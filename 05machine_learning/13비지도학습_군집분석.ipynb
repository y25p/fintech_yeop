# %% [markdown]
# # 비지도학습_군집분석<br> 정답없는 분석
# 예제링크: https://raw.githubusercontent.com/haram4th/ablearn/main/shopping-data.csv
# ![image.png](attachment:image.png)
# 바로 받아오기
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 군집 분석의 분류
# - 비계층적 군집 (대부분)
# - 계층적 군집 (비계층 이외)
#     - 비지도 학습
#     - 데이터가 적을 때 사용
#     - 거리계산지표: 유클리드, 맨하탄, 코사인 유사도
# - 계층적 군집 5가지
#     - 단일연결법(최단연결법)
#     - 완전연결법, 최장연결법
#     - 평균연결법
#     - 중심연결법
#     - 와드연결법
# - 시각화할때) 댄드로그램

# %%
import scipy.cluster.hierarchy as shc
