# %% [markdown]
# # Matplotlib은 파이썬에서 그래프그릴때 사용<br>그래프-시각화 도구
# ![image.png](attachment:image.png)
# https://matplotlib.org/stable/users/getting_started/<br>
# - pip install matplotlib
# - conda install -c conda-forge matplotlib
# ## seaborn 좀더 예쁨
