# %% [markdown]
# # 1.requests 모듈 : HTTP프로토콜을 사용할 수 있게 해주는 모듈
# * requsest모듈 사용 설명서
# [requests](https://requests.readthedocs.io/en/latest/user/quickstart/)

# %% [markdown]
# # 2.requests 모듈 설치
# * conda install requests
# * pip install requests

# %% [markdown]
# # 3. requests 모듈 사용법

# %% [markdown]
# * 1) 모듈 불러오기: import requests
# * 2) url 변수에 저장
# * 3) url 파라미터
#   * payload = {파라미터1 : value, 파라미터2 : value}
# * 4) headers
#   * headers = {key : value}
# * 5) HTTP 요청 보내기 get, post
#   * get: r = requests.get(url, params=payload, headers=headers)
#   * post: r = requests.post(url, data={key:value})
# * 6) 만들어진 url 확인: print(r.url)
# * 7) 응답 코드 확인: print(r.status_code)
# * 8) 응답 요소 출력: r.text, r.content, r.json()

# %%
import requests
url =""
payload = dict()
r = requests.get(url, params=payload)
print(r.url)
print(r.status_code)
response = r.text # r.content, r.json()

# %% [markdown]
# # requests 모듈로 1페이지만 가져오기

# %%
url = "https://openapi.naver.com/v1/search/book.json"
Client_Id = "sk2iKdMANqpvG3Pa2WIJ"
Client_Secret = "by6xHZcrlB"
payload = dict(query="핀테크", display=100, start=start_num, sort="sim")
headers = {"X-Naver-Client-Id": Client_Id,
           "X-Naver-Client-Secret": Client_Secret}
r = requests.get(url, params=payload, headers=headers)
print(r.url)
print(r.status_code)
response = r.json()

# %%
start_num2 = 1
for s_num in range(11):
    if start_num2 < 901:
        print(start_num2)
        start_num2 += 100
    elif start_num2 == 901:
        print(start_num2)
        start_num2 += 99
        print(start_num2)
# Out:
# 1
# 101
# 201
# 301
# 401
# 501
# 601
# 701
# 801
# 901
# 1000

# %%
import requests
start_num = 1
result_json = []
for page in range(11):
    url = "https://openapi.naver.com/v1/search/book.json"
    Client_Id = "sk2iKdMANqpvG3Pa2WIJ"
    Client_Secret = "by6xHZcrlB"
    payload = dict(query="핀테크", display=100, start=start_num, sort="sim")
    headers = {"X-Naver-Client-Id": Client_Id,
               "X-Naver-Client-Secret": Client_Secret}
    r = requests.get(url, params=payload, headers=headers)
    print(r.url)
    print(r.status_code)
    response = r.json()
    result_json.append(response)
    if start_num < 901:
        start_num += 100
    elif start_num == 901:
        start_num += 99
# Out:
# https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=sim
# 200
# https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=101&sort=sim
# 200
# https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=201&sort=sim
# 200
# https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=301&sort=sim
# 200
# https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=401&sort=sim
# 200
# https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=501&sort=sim
# 200
# https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=601&sort=sim
# 200
# https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=701&sort=sim
# 200
# https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=801&sort=sim
# 200
# https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=901&sort=sim
# 200
# https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1000&sort=sim
# 429

# %% [markdown]
# * 모든 검색 결과를 가져오기 위해서는 여러 페이지 정보를 수집
# * 전체 결과 / 1페이지 표시 개수 + 1 = 전체 페이지수
# * start 부분 + 1페이지 표시 개수 = 다음 페이지 데이터 수집 가능
# * 반복문을 이용해서 start 에 100씩 더해서 최대 1000이 되도록 하면 최대한 많은 데이터 수집 가능

# %%
import requests
url = "https://openapi.naver.com/v1/search/book.json"
Client_Id = "sk2iKdMANqpvG3Pa2WIJ"
Client_Secret = "by6xHZcrlB"
payload = dict(query="핀테크", display=100, start=1, sort="sim")
headers = {"X-Naver-Client-Id": Client_Id,
           "X-Naver-Client-Secret": Client_Secret}
r = requests.get(url, params=payload, headers=headers)
print(r.url)
print(r.status_code)
response = r.json()
# Out:
# https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=sim
# 200

# %%
pages = response['total'] // response['display'] + 1
pages
# Out:
# 2

# %%
start_num = 1
response_json2 = []
for page in range(pages):
    url = "https://openapi.naver.com/v1/search/book.json"
    Client_Id = "sk2iKdMANqpvG3Pa2WIJ"
    Client_Secret = "by6xHZcrlB"
    payload = dict(query="핀테크", display=100, start=start_num, sort="sim")
    headers = {"X-Naver-Client-Id": Client_Id,
               "X-Naver-Client-Secret": Client_Secret}
    r = requests.get(url, params=payload, headers=headers)
    print(r.url)
    print(r.status_code)
    response = r.json()
    pages = response['total'] // response['display'] + 1
    response_json2.append(response)
    if start_num == 1000:
        break
    if start_num < 901:
        start_num += 100
    elif start_num == 901:
        start_num += 99
# Out:
# https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=sim
# 200
# https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=101&sort=sim
# 200

# %%
response_json2[1]
# Out:
# {'lastBuildDate': 'Tue, 01 Apr 2025 11:28:31 +0900',
#  'total': 106,
#  'start': 101,
#  'display': 6,
#  'items': [{'title': '핀테크 / 블록체인 기술이 적용된 온라인 시스템 전자결제 / 보안 / 인증 시장 전망과 핵심기술 동향',
#    'link': 'https://search.shopping.naver.com/book/catalog/32438161048',
#    'image': 'https://shopping-phinf.pstatic.net/main_3243816/32438161048.20221227205547.jpg',
#    'author': 'TF정보분석실',
#    'discount': '342000',
#    'publisher': '트렌드포커스',
#    'pubdate': '20190429',
#    'isbn': '9791188774074',
#    'description': '4차 산업혁명 시대에 핀테크와 블록체인이 핵심기술로 떠오르고 있습니다.\n핀테크는 금융서비스 가치와 혁신을 향상시킬 수 있는 비즈니스 모델로 대두되고 있으며 \n블록체인은 세계경제포럼(World Economic Forum, WEF)에서 4차 산업혁명 시대의 핵심\n기술로 선정될 정도로 인정받고 있고 올해까지 전 세계 은행의 80%가 블록체인 기술을 도\n입할 것으로 전망되고 있습니다.\n\n핀테크(fintech)는 금융서비스 도메인에서 IT 기술을 기반으로 새로운 응용프로그램, 프로\n세스, 제품, 비즈니스 모델 또는 새로운 서비스를 제공하는 것으로 이를 통해 금융서비스의 \n가치와 혁신을 향상시키고 있으며 IT기술의 발전에 따라 간편 결제, 대출 프레임워크, 크라\n우드 펀딩등 다양한 형태의 금융서비스가 출시되고 있습니다.\n그리고 블록체인은 금융 분야를 비롯하여 제조 및 유통, 공공서비스, 사회?문화 부문의 \n전영역에 걸쳐 혁신적인 변화를 일으키는 새로운 패러다임이라 말할 수 있습니다.\n\n이에 본 트렌드포커스 TF정보분석실에서는 「핀테크/블록체인 기술이 적용된 온라인 시스\n템 전자결제/보안/인증 시장 전망과 핵심기술 동향」을 발간하게 되었습니다.\n\n본서 I편 1장에서는 핀테크 산업의 전반적 현황, 그리고 2장에서는 핀테크 제품별 산업 동\n향을 분석했으며 3장에서는 핀테크 기술 개발 현황을 정리하였고, II편 1장에서는 블록체인\n산업 현황과 2장에서는 블록체인 제품별 산업 현황, 3장에서는 블록체인 기술 개발 동향을 \n최신 산업조사 자료를 바탕으로 소상히 분석·수록 정리하였으며, 최신 연구개발 사례와 함\n께 소개함으로써 관련 분야 종사자분들에게 도움이 되는 유익한 정보 자료로 활용되기를 \n바랍니다.'},
#   {'title': '신남방 지역 주요국의 핀테크 발전과 협력방안: 인도, 태국, 말레이시아, 베트남, 인도네시아를 중심으로',
#    'link': 'https://search.shopping.naver.com/book/catalog/33234080635',
#    'image': 'https://shopping-phinf.pstatic.net/main_3323408/33234080635.20221019142940.jpg',
#    'author': '이충열^이종하^이선호',
#    'discount': '9000',
#    'publisher': '대외경제정책연구원',
#    'pubdate': '20201231',
#    'isbn': '9788932290201',
#    'description': '이 책은 대외경제정책연구원의 신남방 지역 주요국의 핀테크 발전과 협력방안을 다룬 정부간행물입니다.'},
#   {'title': '[CD] 2018 4차산업 기업.스타트업 주소록 - CD-ROM 1장 (가상현실·드론·로봇·빅데이터·인공지능·핀테크기업, 친환경에너지기업, 창업센터)',
#    'link': 'https://search.shopping.naver.com/book/catalog/32466687247',
#    'image': 'https://shopping-phinf.pstatic.net/main_3246668/32466687247.20221229074014.jpg',
#    'author': '한국콘텐츠미디어',
#    'discount': '170100',
#    'publisher': '한국콘텐츠미디어',
#    'pubdate': '20180921',
#    'isbn': '9791155055663',
#    'description': '2018 4차산업 기업·스타트업 주소록 CD에는 4차 산업기술, 바이오헬스케어, 창업·스타트업, 친환경에너지 관련 회사 주소록이 약 9천 건 수록되어 있다.\n\n※본 CD롬은 엑셀(xls) 형태로 수록되어 있어 사용자가 편리하게 수정·편집·출력할 수 있다.'},
#   {'title': '4차산업 기업·스타트업 주소록(2023)(CD) (IOT, VR, 가상현실, 블록체인, 빅데이터, 스마트팜, 스타트업, 앱개발, 인공지능, 증강현실, 핀테크 등 약 3만 건 수록)',
#    'link': 'https://search.shopping.naver.com/book/catalog/40060224618',
#    'image': 'https://shopping-phinf.pstatic.net/main_4006022/40060224618.20230530082947.jpg',
#    'author': '한국콘텐츠미디어 편집부',
#    'discount': '215100',
#    'publisher': '한국콘텐츠미디어',
#    'pubdate': '20230501',
#    'isbn': '8809496290337',
#    'description': '4차산업 기업·스타트업 주소록을 분야별, 지역별로 18,460건, IT기업 상세정보를 업종별, 지역별로 11,551건을 수록했습니다.\n※엑셀 파일로 사용자가 편리하게 수정·편집·출력할 수 있습니다.'},
#   {'title': '4차산업 기업·스타트업 주소록(2024)(CD) (3D프린터, IOT, VR, 가상현실, 드론, 바이오기업, 스마트공장, 스마트팜, 스타트업, 앱개발, 웨어러블, 인공지능, 핀테크 등 약 5만 6천 건 수록)',
#    'link': 'https://search.shopping.naver.com/book/catalog/46677579619',
#    'image': 'https://shopping-phinf.pstatic.net/main_4667757/46677579619.20240402080440.jpg',
#    'author': '한국콘텐츠미디어 편집부',
#    'discount': '215100',
#    'publisher': '한국콘텐츠미디어',
#    'pubdate': '20240326',
#    'isbn': '9791172340209',
#    'description': '4차산업 기업·스타트업 주소록을 분야별, 지역별로 19,908건, IT기업 상세정보를 업종별, 지역별로 37,091건을 수록했습니다.\n\n주식회사 한국콘텐츠미디어 (부설)한국기업콘텐츠진흥원\n〈〉자료문의= (02)2268-8856~8 www.anyKCM.com'},
#   {'title': '전국 체험마을 주소록(2024)(CD) (3D프린터, IOT, VR, 가상현실, 드론, 바이오기업, 스마트공장, 스마트팜, 스타트업, 앱개발, 웨어러블, 인공지능, 핀테크 등 약 5만 6천 건 수록)',
#    'link': 'https://search.shopping.naver.com/book/catalog/46677576618',
#    'image': 'https://shopping-phinf.pstatic.net/main_4667757/46677576618.20240402101343.jpg',
#    'author': '한국콘텐츠미디어 편집부',
#    'discount': '215100',
#    'publisher': '한국콘텐츠미디어',
#    'pubdate': '20240322',
#    'isbn': '9791172340193',
#    'description': '전국 체험마을 주소록을 분야별, 지역별로 33,479건, 관광·여가산업 상세정보를 업종별, 지역별로 5,018건을 수록했습니다.'}]}

# %% [markdown]
# # While True로 전체데이터 가져오기

# %%
page = 1
start_num2 = 1
response_json3 = []
while True:
    url = "https://openapi.naver.com/v1/search/news.json"
    Client_Id = "sk2iKdMANqpvG3Pa2WIJ"
    Client_Secret = "by6xHZcrlB"
    payload = dict(query="삼성증권 WM 고객 예탁자산", display=100, start=start_num2, sort="sim")
    headers = {"X-Naver-Client-Id": Client_Id,
               "X-Naver-Client-Secret": Client_Secret}
    r = requests.get(url, params=payload, headers=headers)
    print(r.url)
    print(r.status_code)
    response = r.json()
    total_pages = (response['total'] // 100) + 1
    response_json3.append(response)
    if start_num2 == 1000:
        break
    if start_num2 < 901:
        start_num2 += 100
    elif start_num2 == 901:
        start_num2 += 99
    
    if page < total_pages:
        page += 1
    else:
        break
print(len(response_json3))
# Out:
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=101&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=201&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=301&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=401&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=501&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=601&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=701&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=801&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=901&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1000&sort=sim
# 200
# 11

# %% [markdown]
# # 블로그, 책, 뉴스 동시에 수집하기

# %%
import time
response_json3 = []
for category in ["blog", "news", "book"]:
    page = 1
    start_num2 = 1
    while True:
        url = f"https://openapi.naver.com/v1/search/{category}.json"
        Client_Id = "sk2iKdMANqpvG3Pa2WIJ"
        Client_Secret = "by6xHZcrlB"
        payload = dict(query="핀테크", display=100, start=start_num2, sort="sim")
        headers = {"X-Naver-Client-Id": Client_Id,
                   "X-Naver-Client-Secret": Client_Secret}
        r = requests.get(url, params=payload, headers=headers)
        print(r.url)
        print(r.status_code)
        response = r.json()
        total_pages = (response['total'] // 100) + 1
        response_json3.append(response)
        if start_num2 == 1000:
            break
        if start_num2 < 901:
            start_num2 += 100
        elif start_num2 == 901:
            start_num2 += 99

        if page < total_pages:
            page += 1
        else:
            break
        time.sleep(0.5)
print(len(response_json3))
# Out:
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=101&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=201&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=301&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=401&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=501&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=601&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=701&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=801&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=901&sort=sim
# 200
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1000&sort=sim
# 200
# 11
# https://openapi.naver.com/v1/search/news.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=sim
# 200
# https://openapi.naver.com/v1/search/news.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=101&sort=sim
# 200
# https://openapi.naver.com/v1/search/news.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=201&sort=sim
# 200
# https://openapi.naver.com/v1/search/news.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=301&sort=sim
# 200
# https://openapi.naver.com/v1/search/news.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=401&sort=sim
# 200
# https://openapi.naver.com/v1/search/news.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=501&sort=sim
# 200
# https://openapi.naver.com/v1/search/news.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=601&sort=sim
# 200
# https://openapi.naver.com/v1/search/news.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=701&sort=sim
# 200
# https://openapi.naver.com/v1/search/news.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=801&sort=sim
# 200
# https://openapi.naver.com/v1/search/news.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=901&sort=sim
# 200
# https://openapi.naver.com/v1/search/news.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1000&sort=sim
# 200
# 22
# https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=sim
# 200
# https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=101&sort=sim
# 200
# 24

# %% [markdown]
# # 블로그, 뉴스, 책 데이터 각각 저장하기

# %%
import time
keyword = input("검색할 키워드를 입력해 주세요 ")
response_blog = []
response_news = []
response_book = []
for category in ["blog", "news", "book"]:
    page = 1
    start_num2 = 1
    while True:
        url = f"https://openapi.naver.com/v1/search/{category}.json"
        Client_Id = "sk2iKdMANqpvG3Pa2WIJ"
        Client_Secret = "by6xHZcrlB"
        payload = dict(query=keyword, display=100, start=start_num2, sort="sim")
        headers = {"X-Naver-Client-Id": Client_Id,
                   "X-Naver-Client-Secret": Client_Secret}
        r = requests.get(url, params=payload, headers=headers)
        print(r.url, end="\r")
        print(r.status_code, end="\r")
        response = r.json()
        total_pages = (response['total'] // 100) + 1
        
        if category == 'blog':
            response_blog.append(response)
        elif category == "news":
            response_news.append(response)
        elif category == "book":
            response_book.append(response)
                        
        if start_num2 == 1000:
            break
        if start_num2 < 901:
            start_num2 += 100
        elif start_num2 == 901:
            start_num2 += 99

        if page < total_pages:
            page += 1
        else:
            break
        time.sleep(0.5)
print(len(response_blog))
print(len(response_news))
print(len(response_book))
# Out:
# 검색할 키워드를 입력해 주세요 인공지능
# 110ps://openapi.naver.com/v1/search/book.json?query=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&display=100&start=1000&sort=sim
# 11
# 11

# %%
def json_unpack(all_data):
    final_result = {}
    for page in all_data:
        for item in page['items']:
            for key, value in item.items():
                final_result.setdefault(key, []).append(value)
    df = pd.DataFrame(final_result)    
    return df

# %%
for jsons, cat in zip([response_blog, response_news, response_book],["blog", "news", "book"]):
    unpack_result = json_unpack(jsons)
    unpack_result.to_csv(f"naver_{cat}_result.csv", encoding="utf-8", index=False)

# %% [markdown]
# # 3개 카테고리 수집 코드를 함수화하기

# %%
import requests
import time
import os
import pandas as pd

# %%
def naver_search(keyword, category):
    response_result = []
    page = 1
    start_num2 = 1
    while True:
        url = f"https://openapi.naver.com/v1/search/{category}.json"
        Client_Id = "sk2iKdMANqpvG3Pa2WIJ"
        Client_Secret = "by6xHZcrlB"
        payload = dict(query=keyword, display=100, start=start_num2, sort="sim")
        headers = {"X-Naver-Client-Id": Client_Id,
                   "X-Naver-Client-Secret": Client_Secret}
        r = requests.get(url, params=payload, headers=headers)
        print(r.url, end="\r")
        print(r.status_code, end="\r")
        response = r.json()
        total_pages = (response['total'] // 100) + 1
        
        response_result.append(response)
                        
        if start_num2 == 1000:
            break
        if start_num2 < 901:
            start_num2 += 100
        elif start_num2 == 901:
            start_num2 += 99

        if page < total_pages:
            page += 1
        else:
            break
        time.sleep(0.2)
    
    return response_result

# %%
import time
keyword = input("검색할 키워드를 입력해 주세요 ")
for category in ["blog", "news", "book"]:
    naver_search_result = naver_search(keyword, category)
    result_df = json_unpack(naver_search_result)
    display(result_df)
# Out:
# 검색할 키워드를 입력해 주세요 인공지능
# 200ps://openapi.naver.com/v1/search/blog.json?query=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&display=100&start=1000&sort=sim
#                                                   title  \
# 0        제주도 1박2일 여행 스케줄 <b>인공지능</b> 프로그램 챗GPT의 도움을...
# 1                 학점은행제 <b>인공지능</b> 학위 취득 직장인도 할 수 있네요!
# 2                               <b>인공지능</b>학과 체계적인 대비방법
# 3                    고양이홈캠 도기보기 도기캠 <b>인공지능</b>으로 스마트하게
# 4        <b>인공지능</b> 스피커 종류 KT 기가지니4 스펙 요금제 알아보기(lg...
# ...                                                 ...
# 1095                                    <b>인공지능</b>과 사진
# 1096                  <b>인공지능</b>을 활용해 아이 맞춤형 영어 교재 만들기
# 1097                  관악구,<b>인공지능</b>(AI) 아동 그림 심리검사서비스
# 1098  AI <b>인공지능</b> 로봇 알파미니(Alpha Mini)로 배우는 <b>인공지...
# 1099  [한국폴리텍대학 성남캠퍼스] &lt;<b>인공지능</b>소프트웨어과&gt; GV 2...
#
#                                                    link  \
# 0                    https://jongamk.tistory.com/526077
# 1              https://blog.naver.com/2_dl/223813189505
# 2     https://blog.naver.com/blackhole_chinese/22378...
# 3       https://blog.naver.com/sunlovely09/223817969436
# 4         https://blog.naver.com/minsha321/223816637896
# ...                                                 ...
# 1095      https://blog.naver.com/commbooks/223631394459
# 1096   https://blog.naver.com/jonathanshim/223742139185
# 1097        https://blog.naver.com/coreap6/223658753251
# 1098          https://blog.naver.com/mdhb7/223790924778
# 1099  https://blog.naver.com/poly_seongnam/223666247611
#
#                                             description     bloggername  \
# 0     <b>인공지능</b> 프로그램 챗GPT로 떠난 제주 1일차 과연 제주도 여행을 챗G...  핑구야 날자의 IT와 일상
# 1     등에 인공적으로 구현한, 모방한 기능을 갖춘 컴퓨터 시스템으로 이와 같이 지능을 만...       2_dl님의블로그
# 2     <b>인공지능</b>학과 합격자의 후기를 소개합니다 <b>인공지능</b>학과 체계적...       묘한 교육 연구소
# 3     <b>인공지능</b> AI 기능도 추가되어 있어서 반려동물을 좀더 세심하게 맞춤형으...         소중한 나날들
# 4     &quot; &quot; <b>인공지능</b> 스피커, 어떤 제품을 선택해야 좋을까...         일해라 절해라
# ...                                                 ...             ...
# 1095  <b>인공지능</b>은 손과 카메라를 넘어 이미지를 생성하며, GAN 같은 기술은 ...        커뮤니케이션북스
# 1096  <b>인공지능</b>이 고도로 발전하면서 이제 교육계의 오랜 염원이던 학생 맞춤형 ...     심정섭의 학군과 교육
# 1097  관악구,‘<b>인공지능</b>(AI) 아동 그림 심리검사서비스’로 아동학대 예방 총...           새서울신문
# 1098  알파미니는 소형 <b>인공지능</b> 로봇으로, 27cm의 작은 크기를 가지고 있어...            모두행복
# 1099  저는 <b>인공지능</b>소프트웨어과 홍보를 맡게 된 박서현입니다. 성남시에서 주최...   한국폴리텍대학 성남캠퍼스
#
#                            bloggerlink  postdate
# 0         https://jongamk.tistory.com/  20250323
# 1                  blog.naver.com/2_dl  20250328
# 2     blog.naver.com/blackhole_chinese  20250306
# 3           blog.naver.com/sunlovely09  20250401
# 4             blog.naver.com/minsha321  20250331
# ...                                ...       ...
# 1095          blog.naver.com/commbooks  20241024
# 1096       blog.naver.com/jonathanshim  20250130
# 1097            blog.naver.com/coreap6  20241113
# 1098              blog.naver.com/mdhb7  20250310
# 1099      blog.naver.com/poly_seongnam  20241119
#
# [1100 rows x 6 columns]
# 200ps://openapi.naver.com/v1/search/news.json?query=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&display=100&start=1000&sort=sim
#                                                  title  \
# 0           &quot;AI 에어컨 수요 적극 대응&quot;…삼성전자, 생산라인 풀가동
# 1               애플 AI 한국어 지원 시작했지만…이용자 맞춤형 '시리'는 언제 나와
# 2          올트먼 &quot;GPU 녹는다&quot; 행복한 비명…'지브리 프사' 대유행
# 3            중앙대 <b>인공지능</b>인문학연구소, '인문한국 3.0 지원사업' 선정
# 4              금목걸이 절도범 <b>인공지능</b> 선별 관제 시스템에 '딱 걸렸네'
# ...                                                ...
# 1095  경륜·경정 누리집(홈페이지) 전면 재구축 ⋯ <b>인공지능</b> 기반 서비스 강...
# 1096         KAI, <b>인공지능</b> 데이터솔루션 기업 젠젠AI 지분 10% 확보
# 1097            한국표준협회, 고누아이와 '<b>인공지능</b> 인재 양성과정' 개최
# 1098      IBK기업은행, '제3회 해군해병대 <b>인공지능</b>(AI) 경진대회' 후원
# 1099                    AI스타트업 젠젠에이아이, KAI서 120억 투자 유치
#
#                                            originallink  \
# 0            https://www.etoday.co.kr/news/view/2458159
# 1     https://www.newsis.com/view/NISX20250401_00031...
# 2        https://www.hankyung.com/article/202504012315g
# 3     https://edu.donga.com/news/articleView.html?id...
# 4            https://www.news1.kr/local/jeonbuk/5738541
# ...                                                 ...
# 1095              https://www.mk.co.kr/article/11259896
# 1096  https://biz.sbs.co.kr/article_hub/20000221496?...
# 1097  https://www.enetnews.co.kr/news/articleView.ht...
# 1098  https://weekly.cnbnews.com/news/article.html?n...
# 1099     https://www.hankyung.com/article/2025030702041
#
#                                                    link  \
# 0            https://www.etoday.co.kr/news/view/2458159
# 1     https://n.news.naver.com/mnews/article/003/001...
# 2     https://n.news.naver.com/mnews/article/015/000...
# 3     https://edu.donga.com/news/articleView.html?id...
# 4     https://n.news.naver.com/mnews/article/421/000...
# ...                                                 ...
# 1095  https://m.sports.naver.com/general/article/410...
# 1096  https://n.news.naver.com/mnews/article/374/000...
# 1097  https://www.enetnews.co.kr/news/articleView.ht...
# 1098  https://weekly.cnbnews.com/news/article.html?n...
# 1099  https://n.news.naver.com/mnews/article/015/000...
#
#                                             description  \
# 0     이투데이=박민웅 기자 | 삼성전자가 올해 무더위에 따른 에어컨 수요에 신속하게 대응...
# 1     출시 약 반년 만에 한국어 지원을 시작한 애플의 <b>인공지능</b>(AI) 시스템...
# 2     오픈AI가 지난달 25일 선보인 ‘챗GPT-4o’의 새 <b>인공지능</b>(AI)...
# 3     중앙대학교 <b>인공지능</b>인문학연구소가 교육부 산하 한국연구재단이 지원하는 '...
# 4     중고 거래 앱 '당근마켓'을 통해 금목걸이를 건네받은 뒤 오토바이를 타고 도주한 4...
# ...                                                 ...
# 1095  이번 경륜·경정 누리집 개편은 <b>인공지능</b>(AI) 기술을 활용한 순위 예측...
# 1096  한국항공우주산업(KAI)은 6일 <b>인공지능</b>(AI) 기반 국방 합성 데이터...
# 1097  한국표준협회(회장 문동민, 협회)는 인텔 코리아, <b>인공지능</b>(AI) 교육...
# 1098  사진=IBK기업은행 IBK기업은행(은행장 김성태)이 지난 7일 해군해병대 AI 역량...
# 1099  <b>인공지능</b>(AI) 스타트업 젠젠에이아이가 한국항공우주산업(KAI)으로부터...
#
#                               pubDate
# 0     Wed, 02 Apr 2025 08:32:00 +0900
# 1     Wed, 02 Apr 2025 06:01:00 +0900
# 2     Tue, 01 Apr 2025 10:30:00 +0900
# 3     Tue, 01 Apr 2025 16:54:00 +0900
# 4     Tue, 01 Apr 2025 11:23:00 +0900
# ...                               ...
# 1095  Tue, 11 Mar 2025 08:01:00 +0900
# 1096  Fri, 07 Mar 2025 10:58:00 +0900
# 1097  Tue, 18 Mar 2025 15:12:00 +0900
# 1098  Mon, 10 Mar 2025 14:42:00 +0900
# 1099  Fri, 07 Mar 2025 17:32:00 +0900
#
# [1100 rows x 5 columns]
# 200ps://openapi.naver.com/v1/search/book.json?query=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5&display=100&start=1000&sort=sim
#                                                   title  \
# 0                           인공지능 (수학적 이해에서 알고리즘까지, 개정판)
# 1     교실 밖 인공지능 수업 (우리의 상상을 미래의 현실로 만들어가는 인공지능의 세계를 ...
# 2                        AI 리터러시 (인공지능 필수 지식부터 완벽 활용까지)
# 3         된다! 하루 만에 끝내는 챗GPT 활용법 (인공지능에게 일 시키고 시간 버는 법)
# 4                                인공지능 시대의 컴퓨터 개론 (개정8판)
# ...                                                 ...
# 1095       모두의 인공지능 with 스크래치 (누구나 쉽게 만들면서 배우는 인공지능 기초)
# 1096                               브리태니커 만화 백과 51: 인공지능
# 1097                           4차 산업혁명과 인공지능 영어교육 (제2판)
# 1098                                인공지능과 법률 서비스 분야의 혁신
# 1099                       AI의 도전 (인공지능의 위협과 공존 그리고 기회)
#
#                                                    link  \
# 0     https://search.shopping.naver.com/book/catalog...
# 1     https://search.shopping.naver.com/book/catalog...
# 2     https://search.shopping.naver.com/book/catalog...
# 3     https://search.shopping.naver.com/book/catalog...
# 4     https://search.shopping.naver.com/book/catalog...
# ...                                                 ...
# 1095  https://search.shopping.naver.com/book/catalog...
# 1096  https://search.shopping.naver.com/book/catalog...
# 1097  https://search.shopping.naver.com/book/catalog...
# 1098  https://search.shopping.naver.com/book/catalog...
# 1099  https://search.shopping.naver.com/book/catalog...
#
#                                                   image      author discount  \
# 0     https://shopping-phinf.pstatic.net/main_530905...         오상훈    26730
# 1     https://shopping-phinf.pstatic.net/main_337008...         김현정    12600
# 2     https://shopping-phinf.pstatic.net/main_516051...         김용성    22500
# 3     https://shopping-phinf.pstatic.net/main_493627...  프롬프트 크리에이터    15480
# 4     https://shopping-phinf.pstatic.net/main_365674...     김대수^김경동    25760
# ...                                                 ...         ...      ...
# 1095  https://shopping-phinf.pstatic.net/main_324362...         이영호    16200
# 1096  https://shopping-phinf.pstatic.net/main_324363...      봄봄 스토리     9900
# 1097  https://shopping-phinf.pstatic.net/main_324927...         김인석    22500
# 1098  https://shopping-phinf.pstatic.net/main_324776...         양종모    22500
# 1099  https://shopping-phinf.pstatic.net/main_324670...         현대원    18000
#
#      publisher   pubdate           isbn  \
# 0           홍릉  20250311  9791156002635
# 1           궁리  20220725  9788958207788
# 2          프리렉  20241202  9788965404026
# 3      이지스퍼블리싱  20240729  9791163036234
# 4         생능출판  20221227  9788970506173
# ...        ...       ...            ...
# 1095        길벗  20190918  9791160509052
# 1096   미래엔아이세움  20170822  9788937888816
# 1097     한국문화사  20210330  9791166850011
# 1098    한국학술정보  20210331  9791166033940
# 1099      나남출판  20210410  9791197127984
#
#                                             description
# 0
# 1     다가올 새로운 미래를 준비하는 청소년들을 위해 \nIT전문가가 현장에서 들려주는 생...
# 2     AI 시대에 필수로 알아야 할 인공지능의 원리와 개념부터\n학생·직장인·공무원·교육...
# 3     《된다! 하루 만에 끝내는 챗GPT 활용법》이 GPT-4o를 반영한 전면 개정 2판...
# 4     제1장에서는 디지털 혁명과 4차 산업혁명의 시대를 다루었다. 인공지능 기술, 디지털...
# ...                                                 ...
# 1095  개념은 쉽게, 실습은 재밌게! \n남녀노소 누구나 볼 수 있는 실용적인 인공지능 입...
# 1096  미국에서 인공지능을 연구하는 공 박사는 휴가를 맞아 쌍둥이 조카 슬기와 로운이의 집...
# 1097  이 책은 영어교육을 담당하는 전문가들이 4차 산업혁명 시대 정신에 부합하는 영어교육...
# 1098  인공지능의 개념과 개발 동향부터, 법률 서비스 영역에서의 인공지능 알고리즘 활용까지...
# 1099  본격화한 인공지능의 도전, 어떻게 대응할 것인가?\n새로운 ‘초지능의 물결’과 인간...
#
# [1100 rows x 9 columns]

# %%
len(naver_search_result)

# %%
import requests
url = "https://openapi.naver.com/v1/search/blog"
payload = {'query': '핀테크', 'display' : 100, 'start': 1, 'sort' : "sim"}
headers = {"X-Naver-Client-Id" :"sk2iKdMANqpvG3Pa2WIJ", "X-Naver-Client-Secret" : "by6xHZcrlB"}
r = requests.get(url, params=payload, headers=headers)
print(r.url)
print(r.status_code)
data = r.json()
data
# Out:
# https://openapi.naver.com/v1/search/blog?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=sim
# 200
# {'lastBuildDate': 'Mon, 31 Mar 2025 14:38:57 +0900',
#  'total': 456049,
#  'start': 1,
#  'display': 100,
#  'items': [{'title': '<b>핀테크</b> 투자 후기',
#    'link': 'https://blog.naver.com/kan1687/223812724931',
#    'description': '<b>핀테크</b> 투자, 아직도 망설이고 계신가요?  여러분 혹시 이런 고민 해보신 적 있나요? &quot;<b>핀테크</b> 분야가 떴다는데, 지금 시작해도 괜찮을까? 좀 더 상황을 지켜봐야 하나?&quot; 사실 이런 생각은 투자를 고민하는 우리... ',
#    'bloggername': '우정잉♥',
#    'bloggerlink': 'blog.naver.com/kan1687',
#    'postdate': '20250329'},
#   {'title': '[<b>핀테크</b>] 2024년 <b>핀테크</b> 업계 결산: 놀라운 3가지 변화',
#    'link': 'https://blog.naver.com/xoom777/223708685044',
#    'description': '동안 <b>핀테크</b> 업계에는 예상치 못한 변화의 바람이 불었습니다. 한동안 주춤했던 트렌드가... 올 한 해 <b>핀테크</b> 업계를 뜨겁게 달군 3가지 트렌드에 대해 자세히 살펴보겠습니다. 암호화폐의 귀환, 기관... ',
#    'bloggername': 'Ich fange an',
#    'bloggerlink': 'blog.naver.com/xoom777',
#    'postdate': '20241229'},
#   {'title': '[인사이트 캠퍼스] 2025 동계 <b>핀테크</b> 캠프 (with 전주대학교... ',
#    'link': 'https://blog.naver.com/fininsight/223734638126',
#    'description': '전주대학교 친구들이 직접 여의도까지 방문하여 <b>핀테크</b>(FinTech)의 세계를 탐구할 기회를 가질 수... <b>핀테크</b>의 개념부터 해당 기술을 적용하는 사업 분야 그리고 앞으로의 트렌드까지 현업자의 시선에서 면밀하게... ',
#    'bloggername': '핀인사이트 (Fininsight)',
#    'bloggerlink': 'blog.naver.com/fininsight',
#    'postdate': '20250122'},
#   {'title': '[AI <b>핀테크</b>] AI와 빅데이터로 금융 시장을 재편하는 <b>핀테크</b>... ',
#    'link': 'https://blog.naver.com/jangpung_/223765345858',
#    'description': '이제 대출도 AI가 하는 시대 출처 : 파가야 테크놀러지스 홈페이지 금융과 기술이 만나는 <b>핀테크</b>... 제공하는 <b>핀테크</b> 기업으로, 현재 미국, 이스라엘, 케이맨 제도 등여러나라에서 사업을 진행하고 있다.... ',
#    'bloggername': '낭만을 꿈꾸는 일상',
#    'bloggerlink': 'blog.naver.com/jangpung_',
#    'postdate': '20250218'},
#   {'title': 'IPAY <b>핀테크</b>관련주 ETF -미국 CBDC 코인 서비스 실험 확대',
#    'link': 'https://blog.naver.com/jaso_/223736810791',
#    'description': 'IPAY <b>핀테크</b>관련주 ETF -미국 CBDC 코인 서비스 실험 확대 IPAY ETF는 모바일 결제 산업에 투자하는 ETF로 <b>핀테크</b>관련주라고 보시면 되는데요. 이번 포스팅에선 IPAY <b>핀테크</b>관련주 ETF, 투자수익률, 미국 CBDC... ',
#    'bloggername': '미국주식 퍼주마',
#    'bloggerlink': 'blog.naver.com/jaso_',
#    'postdate': '20250130'},
#   {'title': '맨틀 MNT 코인 디파이 <b>핀테크</b> 서비스 소개',
#    'link': 'https://blog.naver.com/tmglove/223781181469',
#    'description': '웹2와 웹3을 아우르며 기관과 개인 그리고 리테일을 위한 다양한 <b>핀테크</b> 서비스 출시를 준비하고 있다고 하는데요. 그래서 오늘은 MNT 코인의 디파이 <b>핀테크</b> 서비스에 대해 알아보겠습니다. <b>핀테크</b>로... ',
#    'bloggername': 'Hello-',
#    'bloggerlink': 'blog.naver.com/tmglove',
#    'postdate': '20250302'},
#   {'title': '[<b>핀테크</b> 리더] # 2024 금융위원회 선정 10대 기업 _ 1편',
#    'link': 'https://blog.naver.com/koreafintech/223675560515',
#    'description': "[<b>핀테크</b> 리더] ⭐ # 2024 금융위원회 선정 10대 기업 _ 1편 금융위원회는 &lt;코리아 <b>핀테크</b> 위크 2024&gt;에서 작년에 이어 'K-Fintech 30' 프로젝트에 선정된 유망 <b>핀테크</b> 기업 10개사를 발굴하여 소개하였습니다. 'K... ",
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20241128'},
#   {'title': '맨틀 네트워크 코인 MNT <b>핀테크</b> 서비스 등장',
#    'link': 'https://blog.naver.com/ghfjvb465/223781841217',
#    'description': '맨틀네트워크 코인 <b>핀테크</b>와 크립토 경계 허물기 소개, 시세, 전망 코하! 경제적 자유 얻기... 이번 포스팅에서는 맨틀네트워크 코인 MNT의 <b>핀테크</b> 분야 진출 서비스 소개에 대한 내용을 함께 알아보는... ',
#    'bloggername': '노마드신지테의 경제적자유얻기 챌린지',
#    'bloggerlink': 'blog.naver.com/ghfjvb465',
#    'postdate': '20250303'},
#   {'title': '신규 상장 더즌 <b>핀테크</b> B2B 기업용 금융통신망 쉿 쉿 조용 조용',
#    'link': 'https://blog.naver.com/2yongki/223805949459',
#    'description': '기업 개요 20017년 설립 기업용 금융 통신망 서비스를 제공하는 <b>핀테크</b> 업체 금융 인프라를 기반으로... ② 경쟁 심화: * <b>핀테크</b> 시장은 경쟁이 치열하며, 새로운 경쟁자의 등장 가능성도 있습니다. * 새로운... ',
#    'bloggername': '행복한남 경제야놀자',
#    'bloggerlink': 'blog.naver.com/2yongki',
#    'postdate': '20250323'},
#   {'title': '테크놀로지스(PGY): AI 기반 대출 혁신의 주목받는 <b>핀테크</b> 기업',
#    'link': 'https://blog.naver.com/an5217/223810108719',
#    'description': '최근 <b>핀테크</b> 업계에서 주목받는 기업 **파가야 테크놀로지스(NASDAQ:PGY)**가 투자자와 애널리스트들... 제공하는 <b>핀테크</b> 기업입니다. 머신러닝 알고리즘을 통해 개인 대출, 자동차 대출, POS(Point-of-Sale)... ',
#    'bloggername': '오늘 하루도 절도있고 검소하게',
#    'bloggerlink': 'blog.naver.com/an5217',
#    'postdate': '20250326'},
#   {'title': '맨틀 코인 전망 디파이를 넘어 <b>핀테크</b>로 확장하는 미래',
#    'link': 'https://blog.naver.com/duswnswlstlf/223782041308',
#    'description': 'WEB2와 WEB3를 아우르는 기업들이 늘어나고 있지만 현실은 <b>핀테크</b> 기업들이 크립토 산업에 진출할 뿐, 크립토 기업들이 <b>핀테크</b> 사업으로 진출한 경우는 없네요. 가끔은 왜 WEB3 기업들은 디파이를 넘어서 WEB2의... ',
#    'bloggername': '이기사 블로그',
#    'bloggerlink': 'blog.naver.com/duswnswlstlf',
#    'postdate': '20250303'},
#   {'title': '서울형 R&amp;D <b>핀테크</b> 기술사업화 지원사업 완벽 가이드!',
#    'link': 'https://blog.naver.com/thebsc777/223802246310',
#    'description': '이번에 서울경제진흥원에서 공고한 25년 서울형 R&amp;D <b>핀테크</b> 기술사업화 지원사업 에 대해 상세히 알아보겠습니다. <b>핀테크</b> 분야 기업이라면 절대 놓치면 안 될 이번 지원사업, 꼼꼼히 살펴볼게요! 1. 지원... ',
#    'bloggername': '정책지원알림',
#    'bloggerlink': 'blog.naver.com/thebsc777',
#    'postdate': '20250323'},
#   {'title': '네이버클라우드 X 서울대학교 KDT 빅데이터 <b>핀테크</b> 전문가 과정',
#    'link': 'https://blog.naver.com/n_cloudplatform/223790788385',
#    'description': '서울대학교 KDT 빅데이터 <b>핀테크</b> 전문가 과정에 캡스톤 참여기업으로 함께한 네이버클라우드의... 서울대학교 빅데이터 <b>핀테크</b> AI 고급 전문가 과정 서울대학교가 주관하는 고용노동부의 K... ',
#    'bloggername': '네이버클라우드 (NAVER Cloud)',
#    'bloggerlink': 'blog.naver.com/n_cloudplatform',
#    'postdate': '20250311'},
#   {'title': '25년 금융 클라우드 지원사업 <b>핀테크</b> 기업 클라우드는... ',
#    'link': 'https://blog.naver.com/xeno_solution/223791865385',
#    'description': '이번에 <b>핀테크</b> 기업 담당하고 계신 분들이 주목할 만한 소식이 업데이트되어 가지고 왔습니다~ 다름... <b>핀테크</b> 기업의 경우 보안 기능과 빠르게 처리가 가능한 인프라를 요구할 수밖에 없습니다. 그렇기... ',
#    'bloggername': '클라우드를 가장 잘 하는 회사, 제노솔루션',
#    'bloggerlink': 'blog.naver.com/xeno_solution',
#    'postdate': '20250311'},
#   {'title': '페이버스와 알아보는 2025 글로벌 <b>핀테크</b> 규제 변화',
#    'link': 'https://blog.naver.com/payverse/223809522693',
#    'description': '2025년 주목해야 할 글로벌 <b>핀테크</b> 규제 변화 안녕하세요, 페이버스 입니다 :) <b>핀테크</b> 산업은 전 세계적으로 빠르게 성장하고 있으며, 이에 따라 각국의 규제 환경도 계속해서 변화하고 있습니다.... ',
#    'bloggername': '페이버스(PayVerse)',
#    'bloggerlink': 'blog.naver.com/payverse',
#    'postdate': '20250326'},
#   {'title': '<b>핀테크</b> 개인 경제에 혁명적 영향을 느끼게 하다',
#    'link': 'https://blog.naver.com/anawoncham/223685650464',
#    'description': '<b>핀테크</b> FinTech는 Finance과 Technology의 결합으로, 최근 몇 년간 급속도로 발전하고 있는 분야예요. 이제는 우리 생활의 많은 부분에서 <b>핀테크</b>는 개인 경제에 혁명인 영향을 느끼게 하고 있는데요. 오늘은... ',
#    'bloggername': '♣ 끄적이내 ♣',
#    'bloggerlink': 'blog.naver.com/anawoncham',
#    'postdate': '20241207'},
#   {'title': '2025년 <b>핀테크</b> 트렌드: 새로운 금융 패러다임과 기회의 장',
#    'link': 'https://blog.naver.com/dismalist/223762273788',
#    'description': '2025년, <b>핀테크</b>(FinTech)는 더 이상 &quot;미래의 금융&quot;이 아닙니다. 바로 우리의 일상에 깊숙이 스며든 현실이자 새로운 금융 패러다임을 형성하는 강력한 동력인데요. 이번 포스팅에서는 2025년 <b>핀테크</b> 산업을... ',
#    'bloggername': '마법고양이의 기묘한 이야기',
#    'bloggerlink': 'blog.naver.com/dismalist',
#    'postdate': '20250216'},
#   {'title': '“<b>핀테크</b>-금융회사-투자기관 만남의 장” ｢제2회 <b>핀테크</b> 오픈... ',
#    'link': 'https://blog.naver.com/blogfsc/223666157308',
#    'description': '-<b>핀테크</b>-금융회사 협업 및 <b>핀테크</b> 기업 투자 유치를 확대하는 교류 행사 -금융위원회, <b>핀테크</b> 산업의 지속 성장을 위해 과감한 디지털 금융정책 추진 금융위원회는 11월 19일(화), 서울 창업허브(공덕)에서... ',
#    'bloggername': '금융위원회 공식 블로그',
#    'bloggerlink': 'blog.naver.com/blogfsc',
#    'postdate': '20241119'},
#   {'title': '<b>핀테크</b> 전문가 국비지원 과정 - KG 이니시스 실무자 멘토링',
#    'link': 'https://blog.naver.com/gkea04/223815900160',
#    'description': '<b>핀테크</b> 산업의 현황과 전망 <b>핀테크</b>(FinTech)는 금융(Finance)과 기술(Technology)의 합성어로, IT 기술을 활용하여 금융 서비스를 제공하는 산업을 말합니다. 최근 몇 년간 <b>핀테크</b> 산업은 빠르게 성장하고 있으며, 이는... ',
#    'bloggername': 'KG 에듀원 교육 상담님의 블로그',
#    'bloggerlink': 'blog.naver.com/gkea04',
#    'postdate': '20250331'},
#   {'title': '[기자단 뉴스] 보험 <b>핀테크</b> 트렌드 (인슈어테크/온디맨드 보험)',
#    'link': 'https://blog.naver.com/koreafintech/223661661653',
#    'description': '보험 <b>핀테크</b> 트렌드 제12기 대학생 기자단 이서현 인슈어테크 인슈어테크는 보험과 기술의 합성어로... 보험 <b>핀테크</b> 트렌드 인슈어테크와 온디맨드 보험은 보험 산업의 혁신을 이끄는 핵심 요소로, 소비자에게... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20241118'},
#   {'title': '<b>핀테크</b>로 외국에 보내는 송금 비용 낮추기',
#    'link': 'https://blog.naver.com/e9pay7200/223790123142',
#    'description': '그중에서도 스마트폰을 이용해 금융업무를 볼 수 있게 해주는 <b>핀테크</b> 기술의 등장으로 금융시장에서 상당한 변화를 맞이하게 됐답니다. <b>핀테크</b>의 등장으로 현재 대부분의 금융업무는 스마트폰을 통해... ',
#    'bloggername': '해외송금이 쉬워지는 순간 이나인페이',
#    'bloggerlink': 'blog.naver.com/e9pay7200',
#    'postdate': '20250310'},
#   {'title': '<b>핀테크</b> 뜻 종류 기업 국내 미국 관련주 총정리!',
#    'link': 'https://blog.naver.com/se4125/223711366625',
#    'description': '<b>핀테크</b>는 금융과 기술의 결합으로, 우리의 금융 생활을 혁신하는 핵심 분야로 떠오르고 있습니다. 간편결제, 대출, 투자, 자산관리가지 <b>핀테크</b>는 더 이상 선택이 아닌 필수가 되고 있는데요. 그런데... ',
#    'bloggername': '자유연구소',
#    'bloggerlink': 'blog.naver.com/se4125',
#    'postdate': '20250101'},
#   {'title': '[4/14까지][서울] 2025년 <b>핀테크</b> 기술사업화 지원사업 공고... ',
#    'link': 'https://blog.naver.com/ilsinbc/223800254706',
#    'description': '기술 [서울] 2025년 <b>핀테크</b> 기술사업화 지원사업 공고(서울형 R&amp;D 지원사업) 소관부처·지자체 : 서울특별시 사업수행기관 : 서울경제진흥원 신청기간 : 2025.03.25 ~ 2025.04.14 사업개요 2025년 <b>핀테크</b>... ',
#    'bloggername': '경영지도사 김진영의 105세 경영',
#    'bloggerlink': 'blog.naver.com/ilsinbc',
#    'postdate': '20250318'},
#   {'title': '<b>핀테크</b> 뜻 투자방법 알아봐요',
#    'link': 'https://blog.naver.com/jungmk1570/223602309573',
#    'description': '오늘은 <b>핀테크</b>(FinTech)를 활용한 소액 투자에 대해 이야기해보려고 해요. 최근 주식시장과 금리인하의 변동성으로 인해 많은 사람들이 안정적인 투자처를 찾고 있습니다. 이러한 상황에서 <b>핀테크</b> 플랫폼을... ',
#    'bloggername': '재테크 허니',
#    'bloggerlink': 'blog.naver.com/jungmk1570',
#    'postdate': '20241001'},
#   {'title': '테솔 컬리지, 2025년 <b>핀테크</b>허브 기업 선정!',
#    'link': 'https://blog.naver.com/tesol_college/223813299337',
#    'description': '2025년 <b>핀테크</b>허브입주기업으로 선정되었습니다! 이번 선정을 통해 테솔컬리지는 영어교육과 기술이 융합된 에듀테크 기반 사업모델을 더욱 본격적으로 전개할 수 있게 되었습니다.  <b>핀테크</b>허브란?... ',
#    'bloggername': '테솔 자격증 : TESOL College',
#    'bloggerlink': 'blog.naver.com/tesol_college',
#    'postdate': '20250328'},
#   {'title': '<b>핀테크</b> 기업을 위한 금융 클라우드 지원 사업 (~4/4)',
#    'link': 'https://blog.naver.com/n_cloudplatform/223790696137',
#    'description': '돈과 개인정보를 다루는 만큼 금융∙<b>핀테크</b> 업계는 보안이 정말 중요한데요. 그렇기 때문에 금융∙<b>핀테크</b> 기업이 혁신적인 서비스를 개발하기 위해선 믿을 수 있는 안전한 클라우드 환경이 꼭... ',
#    'bloggername': '네이버클라우드 (NAVER Cloud)',
#    'bloggerlink': 'blog.naver.com/n_cloudplatform',
#    'postdate': '20250310'},
#   {'title': '<b>핀테크</b>로 바뀐 금융의 미래... 2025 일본 <b>핀테크</b> 혁신기업 연수단',
#    'link': 'https://blog.naver.com/iloveimier/223768487894',
#    'description': '바로 <b>핀테크</b>(FinTech)의 등장 덕분인데요!! 오늘은 우리 생활 속 중요한 부분으로 자리 잡은 <b>핀테크</b>에 대해 좀 더 깊이 알아보고, 이와 관련된 연수 프로그램을 소개해 드리겠습니다! <b>핀테크</b>란? <b>핀테크</b>는... ',
#    'bloggername': '한경협국제경영원(IMI) 블로그',
#    'bloggerlink': 'blog.naver.com/iloveimier',
#    'postdate': '20250221'},
#   {'title': '대한민국의 디지털 금융 혁신: 세계가 주목하는 K-<b>핀테크</b>',
#    'link': 'https://blog.naver.com/tnalsrla2002/223797958470',
#    'description': '대한민국은 최첨단 디지털 금융 기술을 기반으로 <b>핀테크</b>(FinTech) 강국으로 성장하고 있으며, 글로벌... 글로벌 <b>핀테크</b> 시장을 선도하는 대한민국 한국의 <b>핀테크</b> 기업들은 글로벌 시장에 진출하며, 해외에서도... ',
#    'bloggername': 'IT감사팀장이 전하는 보안•감사•포렌식',
#    'bloggerlink': 'blog.naver.com/tnalsrla2002',
#    'postdate': '20250316'},
#   {'title': '[ 업스타트 홀딩스 ] AI와 금융의 만남,<b>핀테크</b> 대출 시장을... ',
#    'link': 'https://blog.naver.com/gopagi7/223814284723',
#    'description': '개요 업스타트 홀딩스(티커: UPST)는 AI 기반 대출 플랫폼을 운영하는 <b>핀테크</b> 기업으로, 전통적인... ㆍ규제 및 경쟁 심화 → <b>핀테크</b> 기업 및 전통 금융기관과 경쟁. 5. 향후 전망 ㆍAI 모델 고도화 → 신용... ',
#    'bloggername': '사고싶은주식',
#    'bloggerlink': 'blog.naver.com/gopagi7',
#    'postdate': '20250329'},
#   {'title': '[<b>핀테크</b>] 2025 <b>핀테크</b> 전망: 주목해야 할 10가지 변화',
#    'link': 'https://blog.naver.com/xoom777/223702449504',
#    'description': '2025년이 다가오면서, 금융 기술, 즉 <b>핀테크</b> 분야에서 흥미로운 변화들이 예상되고 있어. 인공지능의... 이제 2025년에 주목해야 할 10가지 <b>핀테크</b> 트렌드를 함께 살펴보자. 1. 웰스테크(WealthTech)의 부상... ',
#    'bloggername': 'Ich fange an',
#    'bloggerlink': 'blog.naver.com/xoom777',
#    'postdate': '20241223'},
#   {'title': '소셜 <b>핀테크</b>, 왜 사람들이 계속 이용할까?',
#    'link': 'https://blog.naver.com/flyfirst0101/223789749173',
#    'description': '<b>핀테크</b>를 활용해서 2~3천만원의 결혼 자금을 만드는 사람부터 1천만원 이내의 시드머니를 빠른 시간내에 확보하여 투자에 활용하는 사람까지 참여자들이 급속도로 늘어나고 있습니다. 재밌는 점은 소셜 <b>핀테크</b>... ',
#    'bloggername': '아임인 공식 블로그',
#    'bloggerlink': 'blog.naver.com/flyfirst0101',
#    'postdate': '20250309'},
#   {'title': '[기자단 뉴스] 2024년 <b>핀테크</b> 해외 이슈',
#    'link': 'https://blog.naver.com/koreafintech/223621158409',
#    'description': '2024년 <b>핀테크</b> 해외 이슈 제12기 대학생 기자단 이서현 이제는 손바닥 결제 시대? 중국의 텐센트가... 기사를 작성하며 제가 ‘손바닥 결제’와 ‘암호화폐 채굴’이라는 주제를 선택한 이유는 <b>핀테크</b> 분야의... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20241016'},
#   {'title': '아프리카 스타트업 생태계의 <b>핀테크</b> 중심 현상 속 주요... ',
#    'link': 'https://blog.naver.com/viewist/223662800063',
#    'description': "최근 한 자리에서 아프리카 스타트업 생태계의 주요 특징 중 하나가 '<b>핀테크</b> 중심의 성장'이라고... 아프리카 스타트업 생태계는 <b>핀테크</b> 중심지? 가장 최근 유니콘 기업으로 등극한 나이지리아의 모니포인트를... ",
#    'bloggername': '아프리카의 IT와 스타트업 <<AFRITUP 아프릿업>>',
#    'bloggerlink': 'blog.naver.com/viewist',
#    'postdate': '20241116'},
#   {'title': '[프로모션] 최대 9600만원 지원, NHN Cloud <b>핀테크</b> 기업 수요... ',
#    'link': 'https://blog.naver.com/nhncloud_official/223805041831',
#    'description': 'NHN Cloud는 <b>핀테크</b> 기업에게 중요한 안전한 인프라와 폭넓은 기술 지원을 5년 연속 제공하고 있습니다. NHN Cloud의 <b>핀테크</b> 기업을 위한 특별한 혜택을 안내해 드립니다. ‘금융 클라우드 지원사업’이란?... ',
#    'bloggername': '유연하게 안전하게 비즈니스에 힘이 되다 ☁️',
#    'bloggerlink': 'blog.naver.com/nhncloud_official',
#    'postdate': '20250325'},
#   {'title': '<b>핀테크</b> 개발자가 되기 위해 필요한 역량과 취업 준비 방법',
#    'link': 'https://blog.naver.com/alsldd3/223812739187',
#    'description': '<b>핀테크</b> 개발자가 되기 위해 필요한 역량과 취업 준비 방법 안녕하세요. 적어보았다입니다. 최근 금융과 기술이 융합된 <b>핀테크</b> 산업이 빠르게 성장하면서, <b>핀테크</b> 개발자에 대한 수요도 증가하고 있는데요.... ',
#    'bloggername': '✍적어보았다.✍',
#    'bloggerlink': 'blog.naver.com/alsldd3',
#    'postdate': '20250328'},
#   {'title': '<b>핀테크</b> 뜻 관련주 기업 추천앱 예시 알아보기',
#    'link': 'https://blog.naver.com/choi9503/223713796013',
#    'description': '<b>핀테크</b> 뜻 관련주 기업 추천앱 예시 알아보기 최근 몇 년간 <b>핀테크</b>라는 산업의 성장이 눈에 띄게 증가하고 있습니다 특히 아세안 지역에서의 확장이 두드러지고 있는데, 인도네시아나 말레이시아 그리고... ',
#    'bloggername': '부동산 경제 건강 일상 맛집 이야기 !!',
#    'bloggerlink': 'blog.naver.com/choi9503',
#    'postdate': '20250104'},
#   {'title': '<b>핀테크</b> 기업 종류 뜻 및 서비스와 관련 용어',
#    'link': 'https://blog.naver.com/possiblehoya/223387198263',
#    'description': '이번 포스팅에서는 우리나라에서 카카오페이, 네이버페이 등으로 유명한 <b>핀테크</b> 기업 종류와 뜻 그리고 관련 서비스와 용어 등에 대해 정리해 보도록 하겠습니다! <b>핀테크</b> 뜻 무엇일까?! <b>핀테크</b>(FinTech)는... ',
#    'bloggername': '커피 이코노미스트',
#    'bloggerlink': 'blog.naver.com/possiblehoya',
#    'postdate': '20240318'},
#   {'title': '<b>핀테크</b> 뜻 유래 기업 사례',
#    'link': 'https://blog.naver.com/toresi/223471507785',
#    'description': '<b>핀테크</b> 하루 1분 금융경제용어 안녕하세요. ^^ 오늘의 경제용어입니다. <b>핀테크</b> 뜻은 무엇인가? <b>핀테크</b>(FinTech) 금융(Finance)과 기술(Technology)의 합성어로, 금융 서비스를 기술적으로 혁신하여 융합하는 것을... ',
#    'bloggername': '은행원쀼에게 금융 묻고 더블로',
#    'bloggerlink': 'blog.naver.com/toresi',
#    'postdate': '20240607'},
#   {'title': '서울<b>핀테크</b>랩, ‘<b>핀테크</b> 스타트업을 위한 정부지원사업·R&amp;D... ',
#    'link': 'https://blog.naver.com/venturesquare_/223727540072',
#    'description': '서울<b>핀테크</b>랩은 1월 14일 서울<b>핀테크</b>랩에서 <b>핀테크</b> 기업을 대상으로 ‘2025년 서울<b>핀테크</b>랩과 함께하는 <b>핀테크</b> 스타트업을 위한 정부지원사업·R&amp;D·TIPS 알아보기’ 컨퍼런스를 개최하고 마무리했다고 밝혔다.... ',
#    'bloggername': 'VentureSquare',
#    'bloggerlink': 'blog.naver.com/venturesquare_',
#    'postdate': '20250116'},
#   {'title': '[3/26까지][금융위원회]2025년 제1차 <b>핀테크</b> 해외진출 컨설팅... ',
#    'link': 'https://blog.naver.com/ilsinbc/223788341613',
#    'description': '수출 2025년 제1차 <b>핀테크</b> 해외진출 컨설팅 참여기업 모집 공고 소관부처·지자체 : 금융위원회 사업수행기관 : 한국<b>핀테크</b>지원센터 신청기간 : 2025.03.05 ~ 2025.03.26 사업개요 한국<b>핀테크</b>지원센터(이하... ',
#    'bloggername': '경영지도사 김진영의 105세 경영',
#    'bloggerlink': 'blog.naver.com/ilsinbc',
#    'postdate': '20250308'},
#   {'title': '더즌 공모주 수요예측 결과 <b>핀테크</b> 관련주',
#    'link': 'https://blog.naver.com/bss2062/223792343321',
#    'description': '더즌 공모주 수요예측 결과 <b>핀테크</b> 관련주 카카오페이의 자회사로도 알려져 있는 더즌이 내일 청약에... 기업정보 더즌은 인터넷, 모바일을 통해 간편하게 금융 거래를 제공해 주는 <b>핀테크</b> 기업이다. 우리가... ',
#    'bloggername': '슈레카의 경제노트',
#    'bloggerlink': 'blog.naver.com/bss2062',
#    'postdate': '20250311'},
#   {'title': 'K-<b>핀테크</b> 글로벌화를 통한 성장(Scale-up) 지원',
#    'link': 'https://blog.naver.com/blogfsc/223749886170',
#    'description': '2025년 제1차 「<b>핀테크</b> 지원협의체」 개최 -해외진출 지원 프로그램 예산 신설 등 정부·금융회사 연계 해외진출 지원 -코리아 <b>핀테크</b> 위크(AI와 <b>핀테크</b>를 주제로 11월 개최) 글로벌존 확장 예정... ',
#    'bloggername': '금융위원회 공식 블로그',
#    'bloggerlink': 'blog.naver.com/blogfsc',
#    'postdate': '20250206'},
#   {'title': '글로벌 금융 혁신을 향한 도전 : 쿠콘, 싱가폴 <b>핀테크</b> 페스티벌... ',
#    'link': 'https://blog.naver.com/webcashgroup/223660359266',
#    'description': 'WE-하 오늘 전해 드릴 이야기는 최근 비즈니스 데이터 플랫폼 기업 쿠콘이 세계 최대 <b>핀테크</b> 행사인 ‘싱가포르 <b>핀테크</b> 페스티벌 2024’에 참가했다는 소식입니다! 싱가포르 <b>핀테크</b> 페스티벌은 매년 전 세계의... ',
#    'bloggername': '웹케시그룹 공식 블로그',
#    'bloggerlink': 'blog.naver.com/webcashgroup',
#    'postdate': '20241114'},
#   {'title': '이것도 <b>핀테크</b>? 운전 습관에 따라 보험료가... ',
#    'link': 'https://blog.naver.com/koreafintech/223803803517',
#    'description': '이것도 <b>핀테크</b>? #1편 운전 습관에 따라 보험료가 달라지는 BBI (Behavior-Based Insurance) 인슈어테크로... 오늘은 보험의 <b>핀테크</b>인 인슈어테크(InsureTech) 중 “운전행태 기반 자동차 보험 (BBI, Behavior-Based Insurance)... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20250321'},
#   {'title': 'AI <b>핀테크</b>와 재테크',
#    'link': 'https://blog.naver.com/commbooks/223704297144',
#    'description': 'AI와 <b>핀테크</b> 기술이 금융과 재테크 분야를 어떻게 혁신하는지 탐구한다. AI 기반 로보어드바이저와... AI와 <b>핀테크</b> 기술을 효과적으로 활용한 재테크 전략과 함께 윤리적 기준을 고려한 금융 서비스의 미래를... ',
#    'bloggername': '커뮤니케이션북스',
#    'bloggerlink': 'blog.naver.com/commbooks',
#    'postdate': '20241224'},
#   {'title': '경제용어 <b>핀테크</b>,(모바일 시대)',
#    'link': 'https://blog.naver.com/expert_1/223784395284',
#    'description': '<b>핀테크</b>가 무엇인지 그 개념과 어떠한 분야에서 유용하게 쓰이고 있는지 간단하게 정리를 해보겠습니다. <b>핀테크</b>(FinTech/ Financial Technology)는 금융(Finance)과 기술(Technology)이 합쳐진 말입니다. 금융 서비스와... ',
#    'bloggername': '빛을 담는 마법사',
#    'bloggerlink': 'blog.naver.com/expert_1',
#    'postdate': '20250305'},
#   {'title': "'<b>핀테크</b>'에 대해서 알고있나요?",
#    'link': 'https://blog.naver.com/mmdm1989/223669850292',
#    'description': "'<b>핀테크</b>'란 금융(Finance)과 기술(Technology)의 합성어로 금융과 정보통신(IT)기술의 융합을 통한... <b>핀테크</b>는 2000년대 초반, 인터넷이 발달하면서 태동하였습니다. 직접적으로 영향을 미친 것은... ",
#    'bloggername': 'SD명문학원',
#    'bloggerlink': 'blog.naver.com/mmdm1989',
#    'postdate': '20241122'},
#   {'title': '금융의 디지털 혁신을 만들어준 <b>핀테크</b>',
#    'link': 'https://blog.naver.com/kiat_tech/223691416200',
#    'description': '<b>핀테크</b> 2.0 시대 돌입 ✔ <b>핀테크</b>는 스마트폰 등장 이후 디지털 결제, 대출, 투자 등으로 확장된 금융 혁신 기술 ✔ AI 기반 <b>핀테크</b>는 개인화된 금융 비서 역할과 효율성 극대화로 스마트한 금융 서비스 제공... ',
#    'bloggername': '한국산업기술진흥원 블로그',
#    'bloggerlink': 'blog.naver.com/kiat_tech',
#    'postdate': '20241227'},
#   {'title': '금융산업 전문인력 양성 ‘<b>핀테크</b> 캠프’ 운영',
#    'link': 'https://blog.naver.com/leebangheui/223724159445',
#    'description': '전주대학교(총장 박진배) 대학일자리플러스센터는 <b>핀테크</b> 산업에 관심이 있는 재학생 및 졸업생 29명을 대상으로 지난 1월 7일부터 3박 4일 간 서울국제금융센터(One IFC)에서“<b>핀테크</b> 캠프”를 운영했다고... ',
#    'bloggername': 'BANGABANGA',
#    'bloggerlink': 'blog.naver.com/leebangheui',
#    'postdate': '20250113'},
#   {'title': '미국과 영국 <b>핀테크</b>(Fintech)석사 추천학교 (feat.... ',
#    'link': 'https://blog.naver.com/mskonan/223652313232',
#    'description': '요즘 <b>핀테크</b>(Fintech)에 대한 관심이 높아지고 있습니다. 오늘은 미국과 영국에서 <b>핀테크</b>(Fintech)를 공부할수 있는 학교를 살펴보겠습니다. <b>핀테크</b>(Fintech)란 금융(Financial)과 기술... ',
#    'bloggername': '30년 유학전문가의 유학이야기',
#    'bloggerlink': 'blog.naver.com/mskonan',
#    'postdate': '20241108'},
#   {'title': '2025년! 한국 <b>핀테크</b>의 기업공개(IPO)가 시작된다.',
#    'link': 'https://blog.naver.com/sijifs/223710220973',
#    'description': '한국 <b>핀테크</b>의 기업공개(IPO)가 시작된다. 한국 <b>핀테크</b> 기업, 10년만에 흑자 전환 날짜 2024.12.31. 신문사 한국경제 기사제목 &quot;10여년 만의 흑자&quot;…<b>핀테크</b>社 내년 대도약하나 What <b>핀테크</b> 토스 앱을 운영하고... ',
#    'bloggername': '[MitakuyeOyasin] 사진-책-연극-뮤지컬-동물-스페인',
#    'bloggerlink': 'blog.naver.com/sijifs',
#    'postdate': '20241231'},
#   {'title': '[예산소진시까지][금융위원회]2025년 <b>핀테크</b> 보안지원 사업 공고',
#    'link': 'https://blog.naver.com/ilsinbc/223773767425',
#    'description': '기술 2025년 <b>핀테크</b> 보안지원 사업 공고 소관부처·지자체 : 금융위원회 사업수행기관 : 한국<b>핀테크</b>지원센터 신청기간 : 예산 소진시까지 사업개요 오픈뱅킹 참여기업, 금융규제 테스트베드 선정기업... ',
#    'bloggername': '경영지도사 김진영의 105세 경영',
#    'bloggerlink': 'blog.naver.com/ilsinbc',
#    'postdate': '20250225'},
#   {'title': "한국<b>핀테크</b>산업협회, '중소 <b>핀테크</b> 기업을 위한 AML 전략... ",
#    'link': 'https://blog.naver.com/venturesquare_/223731241945',
#    'description': '한국<b>핀테크</b>산업협회(이하 협회)는 Asia Fintech Alliance(AFA·아시아 <b>핀테크</b> 연합)와 공동으로 ‘중소 <b>핀테크</b> 기업을 위한 AML 전략’을 주제로 웨비나를 개최했다. 이번 웨비나는 아시아 14개국의 <b>핀테크</b>... ',
#    'bloggername': 'VentureSquare',
#    'bloggerlink': 'blog.naver.com/venturesquare_',
#    'postdate': '20250120'},
#   {'title': '금융당국이 2024년 총 12회 <b>핀테크</b> 기업들과 소통했습니다.',
#    'link': 'https://blog.naver.com/blogfsc/223696424059',
#    'description': '- 2024년 제12회 ｢찾아가는 금융규제 샌드박스｣ 간담회 개최 - - <b>핀테크</b> 기업들의 규제 관련 의견을 청취하고 금융위 등이 직접 답변을 제공 금융위원회와 금융감독원, 한국<b>핀테크</b>지원센터는 12월 17일 IBK... ',
#    'bloggername': '금융위원회 공식 블로그',
#    'bloggerlink': 'blog.naver.com/blogfsc',
#    'postdate': '20241217'},
#   {'title': 'B2B <b>핀테크</b> 리더 웹케시그룹 공식 홈페이지 한눈에 보기',
#    'link': 'https://blog.naver.com/webcashgroup/223767428095',
#    'description': 'WE-하 B2B <b>핀테크</b> &amp; SaaS 전문 기업 웹케시그룹의 따끈따끈하고 흥미로운 소식들을 전해드리는 웹케시그룹 소식통  WE지기입니다 국내 최초로 기업 자금관리 솔루션을 개발하고, B2B <b>핀테크</b> 시장을 개척해온... ',
#    'bloggername': '웹케시그룹 공식 블로그',
#    'bloggerlink': 'blog.naver.com/webcashgroup',
#    'postdate': '20250220'},
#   {'title': '[슬기로운 <b>핀테크</b> 생활] <b>핀테크</b>, 어디까지 써봤니? 임베디드... ',
#    'link': 'https://blog.naver.com/koreafintech/223664674252',
#    'description': '[슬기로운 <b>핀테크</b> 생활]  # 12 - <b>핀테크</b>, 어디까지 써봤니? 임베디드 금융의 성장 임베디드(Embedded) 금융이란 비금융 기업이 자사 플랫폼 내에 금융 기능을 팁재하여 금융상품과 서비스를 제공하는 형태의... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20241118'},
#   {'title': '[기자단 뉴스] 금융사-<b>핀테크</b> 밋업 상호만남 행사(meet-up)',
#    'link': 'https://blog.naver.com/koreafintech/223619812425',
#    'description': '금융사-<b>핀테크</b> 밋업 상호만남 행사 제12기 대학생 기자단 강영모 금융사-<b>핀테크</b> 밋업은 무엇일까? 지정대리인·위탁테스트 제도 활성화를 위해 `23년 4분기부터 개최 금융회사와 협업을 희망하는 <b>핀테크</b>... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20241015'},
#   {'title': '[한국<b>핀테크</b>지원센터] 금융규제 샌드박스 홈페이지 개편 ②... ',
#    'link': 'https://blog.naver.com/koreafintech/223657582452',
#    'description': "내용 기재 및 파일 업로드가 완료된 경우 '신청하기' 버튼 클릭 * '신청하기' 버튼 클릭 이후에 지정 신청 내용 및 신청서류 변경 불가❗ &lt;제도 신청 관련 문의&gt; 한국<b>핀테크</b> 지원센터 금융혁신부  02-6375-1523, 1525",
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20241114'},
#   {'title': '한국<b>핀테크</b>산업협회, 디지털경제금융연구원과 업무협약 체결',
#    'link': 'https://blog.naver.com/venturesquare_/223717309016',
#    'description': '<b>핀테크</b>산업협회(이하 협회)와 디지털경제금융연구원(이하 연구원)은 6일 한국평가데이터와 디지털금융과 데이터 활용에 관한 업무협약(MOU)을 체결했다. 여의도 오투타워에서 열린 이날 협약식에는 한국<b>핀테크</b>산... ',
#    'bloggername': 'VentureSquare',
#    'bloggerlink': 'blog.naver.com/venturesquare_',
#    'postdate': '20250107'},
#   {'title': '[정책현장] <b>핀테크</b> 생태계의 지속적인 교류 기회를 마련합니다',
#    'link': 'https://blog.naver.com/blogfsc/223667100074',
#    'description': "금융위원회는 제2회 '<b>핀테크</b> 오픈 네트워킹 데이'를 개최하여 <b>핀테크</b> 생태계를 위한 교류의 장을 펼쳤습니다. 김병환 위원장은 <b>핀테크</b> 산업의 앞선 간담회에서 지속적인 성장과 금융회사의 디지털전환을... ",
#    'bloggername': '금융위원회 공식 블로그',
#    'bloggerlink': 'blog.naver.com/blogfsc',
#    'postdate': '20241120'},
#   {'title': '[기자단 뉴스] 글로벌 <b>핀테크</b> 동향 알아보기',
#    'link': 'https://blog.naver.com/koreafintech/223631935495',
#    'description': '글로벌 <b>핀테크</b> 동향 알아보기 제12기 대학생 기자단 이유진 1. 멕시코 <b>핀테크</b> ▶ 2022년 기준 <b>핀테크</b> 거래 규모는 860억 달러로, 전년 동기 대비 23%의 성장률을 보임 ▶ 멕시코 소비자들의 <b>핀테크</b>에 대한... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20241024'},
#   {'title': '[기자단 뉴스] 은행 <b>핀테크</b> 트렌드 살펴보기!',
#    'link': 'https://blog.naver.com/koreafintech/223661351099',
#    'description': '은행 <b>핀테크</b> 트렌드 살펴보기! 제12기 대학생 기자단 이유진 1️⃣ 생성형 AI 활용 ▶️챗봇 등 생성형 AI를 이용하여 고객과 자연어로 소통 ▶️은행과 금융 부문의 생성형 AI 글로벌 시장 규모는 7억... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20241115'},
#   {'title': '<b>핀테크</b> 생활] # 11편 - 레그테크, 기업을 지켜내는 <b>핀테크</b> 기술',
#    'link': 'https://blog.naver.com/koreafintech/223624175755',
#    'description': '[슬기로운 <b>핀테크</b> 생활]  # 11 - 레그테크 기업을 지켜내는 <b>핀테크</b> 기술 레그테크(RegTech)란 Regulation(규제) + Technology(기술) 의 합성어로 쉽게 말해 규제를 관리·준수하는 기술인데요!  금융 환경 변화로... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20241018'},
#   {'title': '[기자단 뉴스] 증권업의 <b>핀테크</b> 트렌드 : 인공지능 (AI) 기반... ',
#    'link': 'https://blog.naver.com/koreafintech/223679827028',
#    'description': '증권업의 <b>핀테크</b> 트렌드 : 인공지능(AI) 기반 자산관리 제12기 대학생 기자단 박소민 증권업에서 &quot;HOT... 게다가 많은 증권사와 <b>핀테크</b> 기업들이 AI를 활용한 로보 어드바이저 같은 솔루션을 빠르게 도입하면서... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20241203'},
#   {'title': '[<b>핀테크</b> 리더] # 2024 글로벌 액셀러레이팅 선정기업',
#    'link': 'https://blog.naver.com/koreafintech/223571950314',
#    'description': '[<b>핀테크</b> 리더]  # 창업진흥원X한국<b>핀테크</b>지원센터 2024 글로벌 액셀러레이팅 선정기업 글로벌 액셀러레이팅 지원사업이란? 해외 진출을 희망하는 유망 창업 기업의 해외 시장조사, 비즈니스 현지화 등을... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20240904'},
#   {'title': "✨한국<b>핀테크</b>지원센터 제13기 대학생 기자단 '핀플루언서... ",
#    'link': 'https://blog.naver.com/koreafintech/223791038196',
#    'description': '&quot;  모집인원 : 개인 10명 내외  모집대상 : <b>핀테크</b>에 관심이 많은 대학교(원)생, 휴학생이라면 누구나!  활동기간 : 2025.4. ~ 2025.12.  주요활동 : 한국<b>핀테크</b>지원센터 공식 SNS 콘텐츠 제작 *<b>핀테크</b> 관련 기사... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20250310'},
#   {'title': '[기자단 뉴스] <b>핀테크</b>큐브 및 디지털 금융기술 내재화 사업... ',
#    'link': 'https://blog.naver.com/koreafintech/223715988975',
#    'description': "<b>핀테크</b>큐브 및 디지털 금융기술 내재화 사업 통합 성과 공유회 제12기 대학생 기자단 이서현 안녕하세요, 한국<b>핀테크</b>지원센터 12기 기자단 이서현입니다. 지난 12월 12일, '2024 <b>핀테크</b> 큐브 및 디지털 금융기술... ",
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20250106'},
#   {'title': '[기자단 뉴스] <b>핀테크</b> 큐브 및 디지털 금융기술내재화 사업 통합... ',
#    'link': 'https://blog.naver.com/koreafintech/223712321836',
#    'description': '<b>핀테크</b>큐브 및 디지털 금융기술 내재화 사업 통합 성과 공유회 제12기 대학생 기자단 강영모 &quot;<b>핀테크</b> 큐브 및 디지털 금융기술 내재화 사업 통합 성과공유회&quot;를 보기 전 알아야 할 사전지식 <b>핀테크</b> 큐브는... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20250102'},
#   {'title': '[기자단 뉴스] <b>핀테크</b> 챌린지 본선 취재',
#    'link': 'https://blog.naver.com/koreafintech/223588517101',
#    'description': '<b>핀테크</b> 챌린지 통합본선 제12기 대학생 기자단 이서현 <b>핀테크</b> 챌린지 사업목적 전국 5개 지역 내 금융사회 안정망 구축, <b>핀테크</b> 관련 우수한 아이디어를 가진 (예비)창업팀 발굴, 아이디어 고도화 지원 주최... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20240919'},
#   {'title': '[슬기로운 <b>핀테크</b> 생활] # 10편 - 디지털 시대의 혁신: AI로... ',
#    'link': 'https://blog.naver.com/koreafintech/223581463101',
#    'description': '[슬기로운 <b>핀테크</b> 생활]  # 10 - 디지털 시대의 혁신 AI로 더욱 스마트해진 금융생활 디지털 시대의 핵심 기술인 AI(인공지능)는 <b>핀테크</b> 산업에도 혁신적인 변화를 가져왔어요. 머신러닝, 빅데이터, LLM*, RAG* 등... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20240912'},
#   {'title': '[<b>핀테크</b> 리더] # 2024 금융위원회 선정 10대 기업 _ 2편',
#    'link': 'https://blog.naver.com/koreafintech/223690989809',
#    'description': "[<b>핀테크</b> 리더] ⭐ # 2024 금융위원회 선정 10대 기업 _ 2편 지난 1편에서는 2024년 'K-Fintech 30' 선정... 오늘은 대한민국의 미래 금융을 주도할 'K-Fintech 30' <b>핀테크</b> 기업 5개사를 계속해서 알아보도록... ",
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20241212'},
#   {'title': '[기자단 뉴스] <b>핀테크</b>에서의 보험 분야 트렌드',
#    'link': 'https://blog.naver.com/koreafintech/223680055632',
#    'description': '<b>핀테크</b>에서의 보험 분야 트렌드 제12기 대학생 기자단 류제형 안녕하세요 한국<b>핀테크</b>지원센터 12기 대학생 기자단 류제형입니다. 이번에 소개할 콘텐츠는 &lt;<b>핀테크</b>에서의 보험 분야 트렌드&gt; 입니다! <b>핀테크</b>는... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20241205'},
#   {'title': '[기자단 뉴스] 자주 쓰는 어플 안에 <b>핀테크</b> 당근 서비스 편',
#    'link': 'https://blog.naver.com/koreafintech/223702998521',
#    'description': '자주 쓰는 어플 안에 <b>핀테크</b> 당근 서비스편 제12기 대학생 기자단 이다은 어떤 어플을 자주... #우리동네 #중고거래 #당근페이 #당근머니 <b>핀테크</b> 기능은 무엇인가요? 당근페이 당근페이는 당근마켓의 자체 결제... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20241223'},
#   {'title': '[<b>핀테크</b> 리더] # 카카오뱅크X한국<b>핀테크</b>지원센터 2024년... ',
#    'link': 'https://blog.naver.com/koreafintech/223606660622',
#    'description': '[<b>핀테크</b> 리더]  카카오뱅크 X 한국<b>핀테크</b>지원센터 # 2024년 2차 <b>핀테크</b> 데모데이 with FIN:NECT 수상기업 FIN:NECT 란? FIN:NECT = Fintech, Finance + Connect What 금융기술과 관련된 창업자, 고객, 서비스를 서로... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20241004'},
#   {'title': '[기자단 뉴스] 우리가 쓰는 앱 속에 숨어 있는 <b>핀테크</b>, 얼마나... ',
#    'link': 'https://blog.naver.com/koreafintech/223703070792',
#    'description': '우리가 쓰는 앱 속에 숨어 있는 <b>핀테크</b>, 얼마나 알고 계신가요?배달의 민족 제12기 대학생 기자단 이서현... 배달의 민족 배달의민족은 단순한 음식 배달 서비스를 넘어, <b>핀테크</b> 기술로 사용자와 배달 파트너에게... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20241223'},
#   {'title': '[기자단 뉴스] <b>핀테크</b> 큐브 성과공유회',
#    'link': 'https://blog.naver.com/koreafintech/223705871280',
#    'description': '<b>핀테크</b> 큐브 성과 공유회 제12기 대학생 기자단 이다은 목록 및 개요 <b>핀테크</b> 큐브란? <b>핀테크</b> 큐브는 <b>핀테크</b> 스타트업의 스케일업 및 국내·외 진출을 지원하기 위해 사무공간 및 <b>핀테크</b> 특화 육성... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20241226'},
#   {'title': '[EVENT] 한국<b>핀테크</b>지원센터 유튜브 영상 시청 이벤트 (~10/25)',
#    'link': 'https://blog.naver.com/koreafintech/223619619409',
#    'description': '한국<b>핀테크</b>지원센터 유튜브 시청 인증 이벤트 ️  참여 방법 ① 한국<b>핀테크</b>지원센터 유튜브 채널 구독하기! ② [제4회 금융회사-<b>핀테크</b> 기업 상호만남(Meet-Up) 행사 현장스케치] 영상 시청... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20241015'},
#   {'title': '[<b>핀테크</b> 리더] # 두바이 <b>핀테크</b> 서밋 2024',
#    'link': 'https://blog.naver.com/koreafintech/223502518687',
#    'description': '[<b>핀테크</b> 리더] ＃두바이 <b>핀테크</b> 서밋 2024 : 글로벌 무대에서 빛나는 한국 <b>핀테크</b> 기업들 글로벌 <b>핀테크</b>의 미래를 선도하는 두바이 <b>핀테크</b> 서밋 100개국 이상의 국가와 200여 개의 <b>핀테크</b> 기업, 그리고 1500여... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20240705'},
#   {'title': '[기자단 뉴스] 코리아 <b>핀테크</b> 위크 2024 현장취재',
#    'link': 'https://blog.naver.com/koreafintech/223594403993',
#    'description': '코리아 <b>핀테크</b> 위크 2024 #<b>핀테크</b>와 인공지능, 금융의 미래를 열다 한국<b>핀테크</b>지원센터 제12기 기자단 이유진 2024 코리아 <b>핀테크</b> 위크 ✅ 주제: <b>핀테크</b>와 인공지능, 금융의 미래를 열다 ✅ 기간: 2024. 08. 27... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20240924'},
#   {'title': '[기자단 뉴스] 대학생의 하루, <b>핀테크</b>와 함께 달라지다 네이버페이',
#    'link': 'https://blog.naver.com/koreafintech/223697452263',
#    'description': '네이버 페이와 함께한 하루, 대학생의 하루, <b>핀테크</b>와 함께 달라지다 제12기 대학생 기자단 강영모... 매 순간 바쁘게 흘러가는 하루, <b>핀테크</b>가 나를 돕고 있다는 걸 이제야 알았다 자세한 정보가 알고 싶다면... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20241218'},
#   {'title': '한국<b>핀테크</b>지원센터, 제17회 대한민국소통어워즈 3관왕 수상!',
#    'link': 'https://blog.naver.com/koreafintech/223657301802',
#    'description': '제17회 대한민국소통어워즈 한국<b>핀테크</b>지원센터 3관왕 수상!  지난 11월 7일, 한국<b>핀테크</b>지원센터에는 아주 좋은 소식이 있었는데요! 바로바로~ 한국프레스센터에서 개최된 제17회 대한민국소통어워즈... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20241112'},
#   {'title': '[기자단 뉴스] 관광객 <b>핀테크</b> 서비스',
#    'link': 'https://blog.naver.com/koreafintech/223556570054',
#    'description': '관광객 <b>핀테크</b> 서비스 택스 리펀드는 기본, 모바일 여권기반 트립패스 제12기 대학생 기자단 강영모... 더 많은 <b>핀테크</b> 소식은 ✔ 한국<b>핀테크</b>지원센터 ✔ 홈페이지에서 확인하세요!  www.fintech.or.kr',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20240822'},
#   {'title': '[기자단 뉴스] 페이업 <b>핀테크</b> 트렌드',
#    'link': 'https://blog.naver.com/koreafintech/223674344436',
#    'description': '페이업 <b>핀테크</b> 트렌드 제12기 대학생 기자단 이다은 디지털 결제의 확산 ① 개인화된 서비스 생성형... 지속 가능성과 사회적 책임 ESG (환경, 사회, 지배구조) <b>핀테크</b> 기업들이 지속 가능성을 고려한 비즈니스... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20241127'},
#   {'title': '[기자단 뉴스] <b>핀테크</b> 전문가 과정 취재 현장',
#    'link': 'https://blog.naver.com/koreafintech/223620952045',
#    'description': '<b>핀테크</b> 전문가 과정 취재 현장 제12기 대학생 기자단 박소민 Q. <b>핀테크</b> 전문가 과정의 시행 목적은? 빠르게 변화하는 디지털 금융 환경에서 필요한 기술적 역량을 스타트업 관계자 및 금융업계 종사자들에게... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20241016'},
#   {'title': '[기자단 뉴스] 코리아 <b>핀테크</b> 위크 2024 현장취재',
#    'link': 'https://blog.naver.com/koreafintech/223594318793',
#    'description': '코리아 <b>핀테크</b> 위크 2024 제12기 대학생 기자단 강영모 코리아 <b>핀테크</b> 위크는 어떤 변화가 있을까? 2023 코리아 <b>핀테크</b> 위크가 중요하게 다루고 있는 내용은? ✅ 주제 ✅ &quot;미래의 <b>핀테크</b>와 만나다&quot; &quot;The New... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20240924'},
#   {'title': '[기자단 뉴스] 우리가 매일 쓰는 앱, 그 안에 <b>핀테크</b>가 숨어... ',
#    'link': 'https://blog.naver.com/koreafintech/223696146340',
#    'description': '우리가 매일 쓰는 앱, 그 안에 <b>핀테크</b>가 숨어 있다! 캐치테이블 제12기 대학생 기자단 박소민 Did you know?... 그런데 혹시 우리가 자주 사용하는 캐치테이블 어플 속에 <b>핀테크</b> 기능이 숨어있다는 사실 알고... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20241217'},
#   {'title': '강연 요약 2025년 AI트렌드와 금융/<b>핀테크</b> 기업의  AI활용 방안',
#    'link': 'https://blog.naver.com/koreafintech/223717174498',
#    'description': '한국 IBM 김지관 상무 강연 요약 2025년 AI 트렌드와 금융/ <b>핀테크</b> 기업의 AI활용 방안 제12기 대학생... #3 <b>핀테크</b> 혁신:Asteria의 사례 Case study 세번째 세션에서는 IBM의 비즈니스 파트너인 <b>핀테크</b>... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20250107'},
#   {'title': '강연 요약 2025년 AI트렌드와 금융/<b>핀테크</b> 기업의  AI활용 방안',
#    'link': 'https://blog.naver.com/koreafintech/223710226937',
#    'description': '한국 IBM 김지관 상무 강연 요약 2025년 AI 트렌드와 금융/ <b>핀테크</b> 기업의 AI활용 방안 제12기... 2025년 AI 트렌드와 금융/<b>핀테크</b> 기업의 AI 활용 방안에 대해 4가지 토픽으로 나누어 강연이... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20241231'},
#   {'title': '[기자단 뉴스] 코리아 <b>핀테크</b> 위크 2024 현장취재',
#    'link': 'https://blog.naver.com/koreafintech/223598413922',
#    'description': '코리아 <b>핀테크</b> 위크 2024 <b>핀테크</b>와 인공지능 금융의 미래를 열다 제12기 대학생 기자단 남현영 코리아<b>핀테크</b>위크 행사 소개 ♀️ 코리아<b>핀테크</b>위크 2024를 소개합니다!  행사기간 2024.08.27(화) - 2024.08.29(목)... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20240927'},
#   {'title': '한국<b>핀테크</b>지원센터 제12기 대학생기자단 모집',
#    'link': 'https://blog.naver.com/koreafintech/223341942440',
#    'description': '한국<b>핀테크</b>지원센터에서 제 12기 대학생 기자단을 모집합니다!  모집인원 개인 10명 내외  모집대상 <b>핀테크</b>에 관심이 많은 대학교(원)생, 휴학생이라면 누구나!  활동기간 2024.3. - 2024.12.  주요활동... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20240202'},
#   {'title': '[EVENT] <b>핀테크</b>! 내 소원을 들어줘~ 이벤트 (~12/20)',
#    'link': 'https://blog.naver.com/koreafintech/223687608659',
#    'description': '[EVENT] ✨ <b>핀테크</b>! 내 소원을 들어줘~ ✨ 여러분의 생활에 필요한 <b>핀테크</b> 서비스는 무엇인가요?! 항상 여러분의 의견에 귀 기울이는 한국<b>핀테크</b>지원센터는 찐 소비자의 입장에서 사용하고 싶은 <b>핀테크</b>... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20241209'},
#   {'title': '[기자단 뉴스] <b>핀테크</b> 아이디어 공모전 본선 취재',
#    'link': 'https://blog.naver.com/koreafintech/223593257898',
#    'description': '<b>핀테크</b> 아이디어 공모전 본선 제12기 대학생 기자단 이다은 본선 현장으로 가기 전에 <b>핀테크</b> 아이디어 공모전이란? ✅ 공모 자격 ✅ <b>핀테크</b> 관련 아이디어를 가진 사람 공모전 일정에 참여 가능한 자 우수상... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20240923'},
#   {'title': '[기자단 뉴스] 코리아 <b>핀테크</b> 위크 2024 현장취재',
#    'link': 'https://blog.naver.com/koreafintech/223595580508',
#    'description': "코리아 <b>핀테크</b> 위크 2024 현장 살펴보기 제12기 대학생 기자단 이다은 행사 개요 일시: 24.8.27일(화) ~ 8.29일(목) 장소: 동대문디자인플라자(DDP) 아트홀 주제: '<b>핀테크</b>와 인공지능, 금융의 미래를 열다... ",
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20240925'},
#   {'title': '대한민국 <b>핀테크</b> 산업이 세계로 도약할 수 있도록 함께... ',
#    'link': 'https://blog.naver.com/ohsehoon4u/223784864428',
#    'description': "'<b>핀테크</b> 스타트업 간담회'에 참석하여 규제개선 관련 제안과 현장의 애로사항을 청취했습니다. 국내 최대 <b>핀테크</b> 스타트업 육성기관인 ‘서울<b>핀테크</b>랩’은 현재까지 총 368개 기업의 성장을 지원해왔는데요.... ",
#    'bloggername': '오세훈 서울특별시장',
#    'bloggerlink': 'blog.naver.com/ohsehoon4u',
#    'postdate': '20250305'},
#   {'title': '#코리아<b>핀테크</b>위크2024 찐 방문 후기! [금융프렌즈]',
#    'link': 'https://blog.naver.com/blogfsc/223574220858',
#    'description': '코리아 <b>핀테크</b> 위크 2024 2024.8.27~8.29 <b>핀테크</b> 산업에 활력을 불어넣고, 금융혁신을 가속화하는 <b>핀테크</b> 축제의 장! &quot;생생 후기 알려드려요~&quot; &quot;여러분은 <b>핀테크</b>에 대해서 얼마나 알고 계시나요?&quot;  <b>핀테크</b>란?... ',
#    'bloggername': '금융위원회 공식 블로그',
#    'bloggerlink': 'blog.naver.com/blogfsc',
#    'postdate': '20240906'},
#   {'title': '[기자단 뉴스] 코리아 <b>핀테크</b> 위크 2024 성과 알아보기',
#    'link': 'https://blog.naver.com/koreafintech/223622476920',
#    'description': '코리아 <b>핀테크</b> 위크 2024 성과 알아보기 제12기 대학생 기자단 이다은 <b>핀테크</b>와 인공지능, 금융의 미래를 열다 &quot;<b>핀테크</b>와 인공지능, 금융의 미래를 열다&quot;라는 주제로 제6회 코리아 <b>핀테크</b> 위크 2024가... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20241017'},
#   {'title': '[EVENT] 한국<b>핀테크</b>지원센터 글짓기 이벤트',
#    'link': 'https://blog.naver.com/koreafintech/223658986078',
#    'description': '[EVENT] ️ 한국<b>핀테크</b>지원센터 글짓기 이벤트 ️ Q. <b>핀테크</b>를 한마디로 표현한다면?! &quot;나에게 <b>핀테크</b>란?&quot; 여러분에게 <b>핀테크</b>는 어떤 의미인지 맘껏 표현해주세요! 추첨을 통해 푸짐한 선물을... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20241114'},
#   {'title': "[EVENT] 제13기 <b>핀테크</b> 기자단 '핀플루언서' 모집 소문내기... ",
#    'link': 'https://blog.naver.com/koreafintech/223795571369',
#    'description': "* 이벤트 기간 내 공유글 삭제시 제외됩니다.  많은 참여 부탁드립니다  제13기 대학생 기자단 '핀플루언서' 모집에 대한 자세한 정보는 한국<b>핀테크</b>지원센터 포털 내 공지사항을 확인해주세요!  &quot; &quot;",
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20250314'},
#   {'title': '[기자단 뉴스] 우리 주변에 있는 <b>핀테크</b> 찾기',
#    'link': 'https://blog.naver.com/koreafintech/223684569986',
#    'description': '우리 주변에 있는 <b>핀테크</b> 찾기 쿠팡 편! 제12기 대학생 기자단 남현영 무한대로 편리함을 주고 있는... 어떤 <b>핀테크</b> 기능이 있는지 알아보자! 쿠팡페이 ; 전자결제 대행 서비스 쿠팡페이 쿠팡의 자체 결제... ',
#    'bloggername': '한국핀테크지원센터',
#    'bloggerlink': 'blog.naver.com/koreafintech',
#    'postdate': '20241209'},
#   {'title': '서울경제진흥원 <b>핀테크</b> DX 기획자 양성과정(종로캠퍼스)',
#    'link': 'https://solatech.tistory.com/513',
#    'description': '서울시경제진흥원 <b>핀테크</b> DC 기획자 양성과정 3기의 모집이 시작되었습니다. 이 과정은 2023년 6월 개강해서 9월에 종료된 과정으로 당시에는 Web3.0 <b>핀테크</b> 서비스 기획자 과정으로 진행이 되었는데... ',
#    'bloggername': "김재벌(Suk's)의 IT 이야기",
#    'bloggerlink': 'https://solatech.tistory.com/',
#    'postdate': '20241012'}]}

# %%
payload
# Out:
# {'query': '핀테크', 'display': 100, 'start': 1, 'sort': 'sim'}

# %%
headers
# Out:
# {'client_id': 'sk2iKdMANqpvG3Pa2WIJ', 'client_secret': 'by6xHZcrlB'}

# %% [markdown]
# 네이버 검색 API를 이용해서 책을 검색하고 결과를 데이터프레임으로 만드세요.
# * 검색어는 input()을 이용해서 입력받은 값을 이용하세요.

# %%
import requests
import pandas as pd

# %%
def json_unpack(data):
    result = {}
    for item in data['items']:
        for key, value in item.items():
            result.setdefault(key, []).append(value)
    df = pd.DataFrame(result)
    return df

# %%
keyword = input("검색할 키워드를 입력해 주세요: ")
# Out:
# 검색할 키워드를 입력해 주세요: MTS

# %%
url = "https://openapi.naver.com/v1/search/news.json"
Client_Id = "sk2iKdMANqpvG3Pa2WIJ"
Client_Secret = "by6xHZcrlB"
headers = {"X-Naver-Client-Id" : Client_Id, "X-Naver-Client-Secret" : Client_Secret}
payload = dict(query=keyword, display=100, start=1000, sort="sim")
r = requests.get(url, params=payload, headers=headers)
print(r.url)
print(r.status_code)
data = r.json()
print("전체 검색 데이터 수: ", data['total'], "검색할 페이지수: ", (int(data['total'])//100)+1)
result_df = json_unpack(data)
result_df
# Out:
# https://openapi.naver.com/v1/search/news.json?query=MTS&display=100&start=1000&sort=sim
# 200
# 전체 검색 데이터 수:  112911 검색할 페이지수:  1130
#                                                 title  \
# 0            현대차증권, <b>MTS</b> '내일'에 AI 종목 브리핑 서비스 출시
# 1   현대차증권, <b>MTS</b> ‘내일’ AI 종목 브리핑 서비스 출시…미국 주식까...
# 2             현대차증권, <b>MTS</b> ‘내일’ AI 종목 브리핑 서비스 출시
# 3             현대차증권, <b>MTS</b> '내일' AI 종목 브리핑 서비스 출시
# 4          현대차증권, <b>MTS</b> '내일'에 AI 브리핑 도입…美 공시도 제공
# ..                                                ...
# 95         키움증권, <b>MTS</b> 매수·매도 체결 1시간여 먹통…“현재 정상화”
# 96  키움증권 HTS·<b>MTS</b>, 개장 직후 거래장애… &quot;원인 파악 중...
# 97                      키움증권, <b>MTS</b>·HTS 주문 체결 지연
# 98  [속보] 키움증권, <b>MTS</b> 매수·매도 체결 오류...&quot;원인 파...
# 99                     [속보] 키움증권, <b>MTS</b> 주문 체결 오류
#
#                                          originallink  \
# 0   http://www.seoulfn.com/news/articleView.html?i...
# 1          https://www.etoday.co.kr/news/view/2465419
# 2   https://biz.heraldcorp.com/article/10473749?re...
# 3   http://www.shinailbo.co.kr/news/articleView.ht...
# 4      https://www.hankyung.com/article/202504255336i
# ..                                                ...
# 95              https://www.etnews.com/20250403000085
# 96  http://www.fieldnews.kr/news/articleView.html?...
# 97  https://biz.chosun.com/stock/stock_general/202...
# 98  https://www.ddaily.co.kr/page/view/20250403093...
# 99        https://news.dealsitetv.com/articles/152974
#
#                                                  link  \
# 0   http://www.seoulfn.com/news/articleView.html?i...
# 1          https://www.etoday.co.kr/news/view/2465419
# 2   https://n.news.naver.com/mnews/article/016/000...
# 3   http://www.shinailbo.co.kr/news/articleView.ht...
# 4   https://n.news.naver.com/mnews/article/015/000...
# ..                                                ...
# 95  https://n.news.naver.com/mnews/article/030/000...
# 96  http://www.fieldnews.kr/news/articleView.html?...
# 97  https://n.news.naver.com/mnews/article/366/000...
# 98  https://n.news.naver.com/mnews/article/138/000...
# 99        https://news.dealsitetv.com/articles/152974
#
#                                           description  \
# 0   현대차증권은 <b>MTS</b>(모바일트레이딩시스템) '내일'에 인공지능(AI)을 ...
# 1   이투데이=박정호 기자 | 현대차증권은 모바일트레이딩시스템(<b>MTS</b>) ‘내...
# 2   현대차증권은 모바일트레이딩시스템(<b>MTS</b>) ‘내일’에 인공지능(AI)을 ...
# 3   현대차증권은 현대차증권 <b>MTS</b>(모바일트레이딩시스템) '내일'에 인공지능...
# 4   현대차증권은 자사 모바일트레이딩시스템(<b>MTS</b>) ‘내일’에 인공지능(AI...
# ..                                                ...
# 95  키움증권 모바일트레이딩시스템(<b>MTS</b>)가 장 시작 직후 매매체결이 안 되...
# 96  키움증권의 홈트레이딩 시스템(HTS)과 모바일 트레이딩 시스템(<b>MTS</b>)...
# 97  키움증권의 홈·모바일 트레이딩 시스템(HTS·<b>MTS</b>)에서 주문 체결이 ...
# 98  키움증권 모바일트레이딩시스템(<b>MTS</b>)에서 장 시장 직후 오류가 생긴 것...
# 99  키움증권 모바일트레이딩시스템(<b>MTS</b>)에서 장초반 오류가 발생했다. 3일...
#
#                             pubDate
# 0   Fri, 25 Apr 2025 10:18:00 +0900
# 1   Fri, 25 Apr 2025 10:20:00 +0900
# 2   Fri, 25 Apr 2025 10:15:00 +0900
# 3   Fri, 25 Apr 2025 10:12:00 +0900
# 4   Fri, 25 Apr 2025 10:07:00 +0900
# ..                              ...
# 95  Thu, 03 Apr 2025 09:39:00 +0900
# 96  Thu, 03 Apr 2025 09:36:00 +0900
# 97  Thu, 03 Apr 2025 09:37:00 +0900
# 98  Thu, 03 Apr 2025 09:34:00 +0900
# 99  Thu, 03 Apr 2025 09:32:00 +0900
#
# [100 rows x 5 columns]

# %% [markdown]
# # 네이버 API로 검색한 결과 최대한 가져오기
# * 1회 네이버 서버에 요청
# * 응답에서 total을 찾아서 display로 나누어 총 반복할 페이지 산출
# * 반복문 작성 및 종료 조건 설정
# * start가 1, 101, 201, 301 처럼 변경되어야 함, start의 max값은 1000
# * 1페이지 결과를 데이터 프레임으로 만들고 리스트에 append
# * 반복이 끝난 후 리스트에 append된 데이터 프레임을 1개로 합침

# %% [markdown]
# # for문을 이용해서 전체 페이지 가져오기

# %%
keyword = input("검색할 키워드를 입력해 주세요: ")
# Out:
# 검색할 키워드를 입력해 주세요: 파이썬

# %%
all_data = []

# %%
url = "https://openapi.naver.com/v1/search/book.json"
Client_Id = "sk2iKdMANqpvG3Pa2WIJ"
Client_Secret = "by6xHZcrlB"
headers = {"X-Naver-Client-Id" : Client_Id, "X-Naver-Client-Secret" : Client_Secret}
payload = dict(query=keyword, display=100, start=1, sort="sim")
r = requests.get(url, params=payload, headers=headers)
print(r.url)
print(r.status_code)
data = r.json()
n_data = data['total']
total_pages = (int(data['total'])//100)+1
print("전체 검색 데이터 수: ", n_data, "검색할 페이지수: ", total_pages )
result_df = json_unpack(data)
all_data.append(result_df)
# Out:
# https://openapi.naver.com/v1/search/book.json?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&display=100&start=1&sort=sim
# 200
# 전체 검색 데이터 수:  1113 검색할 페이지수:  12

# %%
start = 101
for page in range(total_pages):
    print(f"{page+1}/{total_pages} 수집중", end="\r")
    url = "https://openapi.naver.com/v1/search/book.json"
    Client_Id = "sk2iKdMANqpvG3Pa2WIJ"
    Client_Secret = "by6xHZcrlB"
    headers = {"X-Naver-Client-Id" : Client_Id, "X-Naver-Client-Secret" : Client_Secret}
    payload = dict(query=keyword, display=100, start=start, sort="sim")
    r = requests.get(url, params=payload, headers=headers)
    print(r.url)
    print(r.status_code)
    data = r.json()
    n_data = data['total']
    total_pages = (int(data['total'])//100)+1
#     print("전체 검색 데이터 수: ", n_data, "검색할 페이지수: ", total_pages )
    result_df = json_unpack(data)
    all_data.append(result_df)
    if start == 1000:
        break
    elif start < 901:
        start += 100
    elif start == 901:
        start += 99
# Out:
# https://openapi.naver.com/v1/search/book.json?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&display=100&start=101&sort=sim
# 200
# https://openapi.naver.com/v1/search/book.json?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&display=100&start=201&sort=sim
# 200
# https://openapi.naver.com/v1/search/book.json?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&display=100&start=301&sort=sim
# 200
# https://openapi.naver.com/v1/search/book.json?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&display=100&start=401&sort=sim
# 200
# https://openapi.naver.com/v1/search/book.json?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&display=100&start=501&sort=sim
# 200
# https://openapi.naver.com/v1/search/book.json?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&display=100&start=601&sort=sim
# 200
# https://openapi.naver.com/v1/search/book.json?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&display=100&start=701&sort=sim
# 200
# https://openapi.naver.com/v1/search/book.json?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&display=100&start=801&sort=sim
# 200
# https://openapi.naver.com/v1/search/book.json?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&display=100&start=901&sort=sim
# 200
# https://openapi.naver.com/v1/search/book.json?query=%ED%8C%8C%EC%9D%B4%EC%8D%AC&display=100&start=1000&sort=sim
# 200

# %%
len(all_data)
# Out:
# 11

# %%
final_result = pd.concat(all_data)
final_result = final_result.reset_index(drop=True)
final_result
# Out:
#                                                   title  \
# 0     혼자 만들면서 공부하는 파이썬 (37개 라이브러리와 API로 보고서, 차트, 게임,...
# 1                  혼자 공부하는 파이썬 (1:1 과외하듯 배우는 프로그래밍 자습서)
# 2              Do it! 점프 투 파이썬 (중학생도 첫날부터 실습하는 초고속 입문서)
# 3        밑바닥부터 시작하는 딥러닝 1(리마스터판) (파이썬으로 익히는 딥러닝 이론과 구현)
# 4     50개의 프로젝트로 완성하는 파이썬 업무 자동화 (프로젝트 따라하기로 업무 자동화 ...
# ...                                                 ...
# 1095  챗GPT와 업무자동화 (1분 만에 끝내는 엑셀, 구글 시트, 파워포인트, 파이썬 자...
# 1096  프로그래밍 정석(개념을 잡아주는) (기초 연산부터 고급 문제해결 능력까지 파이썬을 ...
# 1097  머신러닝 딥러닝을 이용한 A.I. 자율주행 RC카 프로젝트 with 파이썬+아두이노...
# 1098         파이썬 딥러닝 파이토치(Python Deep Learning PyTorch)
# 1099  Let’s Start Coding with Raptor & Python (랩터 & ...
#
#                                                    link  \
# 0     https://search.shopping.naver.com/book/catalog...
# 1     https://search.shopping.naver.com/book/catalog...
# 2     https://search.shopping.naver.com/book/catalog...
# 3     https://search.shopping.naver.com/book/catalog...
# 4     https://search.shopping.naver.com/book/catalog...
# ...                                                 ...
# 1095  https://search.shopping.naver.com/book/catalog...
# 1096  https://search.shopping.naver.com/book/catalog...
# 1097  https://search.shopping.naver.com/book/catalog...
# 1098  https://search.shopping.naver.com/book/catalog...
# 1099  https://search.shopping.naver.com/book/catalog...
#
#                                                   image  \
# 0     https://shopping-phinf.pstatic.net/main_528593...
# 1     https://shopping-phinf.pstatic.net/main_325076...
# 2     https://shopping-phinf.pstatic.net/main_403540...
# 3     https://shopping-phinf.pstatic.net/main_526155...
# 4     https://shopping-phinf.pstatic.net/main_537377...
# ...                                                 ...
# 1095  https://shopping-phinf.pstatic.net/main_386135...
# 1096  https://shopping-phinf.pstatic.net/main_324972...
# 1097  https://shopping-phinf.pstatic.net/main_324665...
# 1098  https://shopping-phinf.pstatic.net/main_324549...
# 1099  https://shopping-phinf.pstatic.net/main_324972...
#
#                           author discount       publisher   pubdate  \
# 0                            문현일    23400           한빛미디어  20250214
# 1                            윤인성    19800           한빛미디어  20220601
# 2                            박응용    19800         이지스퍼블리싱  20230615
# 3                         사이토 고키    23400           한빛미디어  20250124
# 4                           오토코더    19800  위즈앤북(Wiznbook)  20250317
# ...                          ...      ...             ...       ...
# 1095                         김철수    16200            위키북스  20230321
# 1096  제니퍼 캠벨^폴 그리스^제이슨 몬토조^그렉 윌슨        0           에이콘출판  20100504
# 1097                         서민우        0             앤써북  20220520
# 1098                 이경택^방성수^안상준    14800           정보문화사  20201008
# 1099                         김충석        0           앤아이컴즈  20190815
#
#                isbn                                        description
# 0     9791169213271  “파이썬을 배워서 어디에 활용할 수 있을지 궁금했나요?”\n나의 신용카드 내역 분석...
# 1     9791162245651  혼자 해도 충분하다! 1:1 과외하듯 배우는 파이썬 프로그래밍 자습서\n\n『혼자 ...
# 2     9791163034735  프로그래밍 분야 8년 연속 베스트셀러!\n《Do it! 점프 투 파이썬》 전면 개정...
# 3     9791169213387  딥러닝 분야 부동의 베스트셀러!\n머리로 이해하고 손으로 익히는 가장 쉬운 딥러닝 ...
# 4     9791198685353  ㆍ퀴즈와 QR 코드 생성부터 나만의 음성 비서 제작까지 다양한 프로젝트 대공개!\n...
# ...             ...                                                ...
# 1095  9791158394288  코드 한 줄 몰라도 1분 만에 끝내는 엑셀, 구글 스프레드시트, 파워포인트 업무 자...
# 1096  9788960771338  『개념을 잡아주는 프로그래밍 정석』은 기본적인 프로그래밍 요소부터 알고리즘, 디버깅...
# 1097  9791185553979  〈머신러닝 딥러닝을 이용한 A.I. 자율주행 RC카 프로젝트 with 파이썬+아두이...
# 1098  9788956748573  파이썬은 선택이 아닌 필수! 파이토치로 딥러닝 입문하기!\n\n이 책은 딥러닝 기술...
# 1099  9788993163568                     ▶ 이 책은 Python(파이썬)을 다룬 이론서입니다.
#
# [1100 rows x 9 columns]

# %% [markdown]
# # While 문으로 데이터 모두 가져오기

# %%
import requests
import pandas as pd
from datetime import datetime

# %%
keyword = input("검색 키워드를 입력해 주세요. ")
# Out:
# 검색 키워드를 입력해 주세요. mpop

# %%
all_data2 = []
start = 1

while True:
    url = "https://openapi.naver.com/v1/search/cafearticle.json"
    Client_Id = "sk2iKdMANqpvG3Pa2WIJ"
    Client_Secret = "by6xHZcrlB"
    headers = {"X-Naver-Client-Id" : Client_Id, "X-Naver-Client-Secret" : Client_Secret}
    payload = dict(query=keyword, display=100, start=start, sort="sim")
    r = requests.get(url, params=payload, headers=headers)
    print(r.url)
    print(r.status_code)
    data = r.json()
    n_data = data['total']
    total_pages = (int(data['total'])//100)+1
    print("전체 검색 데이터 수: ", n_data, "검색할 페이지수: ", total_pages )
    result_df = json_unpack(data)
    all_data2.append(result_df)
    if start == 1000:
        break
    elif start < 901:
        start += 100
    elif start == 901:
        start += 99
# Out:
# https://openapi.naver.com/v1/search/cafearticle.json?query=mpop&display=100&start=1&sort=sim
# 200
# 전체 검색 데이터 수:  2630 검색할 페이지수:  27
# https://openapi.naver.com/v1/search/cafearticle.json?query=mpop&display=100&start=101&sort=sim
# 200
# 전체 검색 데이터 수:  2630 검색할 페이지수:  27
# https://openapi.naver.com/v1/search/cafearticle.json?query=mpop&display=100&start=201&sort=sim
# 200
# 전체 검색 데이터 수:  2630 검색할 페이지수:  27
# https://openapi.naver.com/v1/search/cafearticle.json?query=mpop&display=100&start=301&sort=sim
# 200
# 전체 검색 데이터 수:  2630 검색할 페이지수:  27
# https://openapi.naver.com/v1/search/cafearticle.json?query=mpop&display=100&start=401&sort=sim
# 200
# 전체 검색 데이터 수:  2630 검색할 페이지수:  27
# https://openapi.naver.com/v1/search/cafearticle.json?query=mpop&display=100&start=501&sort=sim
# 200
# 전체 검색 데이터 수:  2630 검색할 페이지수:  27
# https://openapi.naver.com/v1/search/cafearticle.json?query=mpop&display=100&start=601&sort=sim
# 200
# 전체 검색 데이터 수:  2630 검색할 페이지수:  27
# https://openapi.naver.com/v1/search/cafearticle.json?query=mpop&display=100&start=701&sort=sim
# 200
# 전체 검색 데이터 수:  2630 검색할 페이지수:  27
# https://openapi.naver.com/v1/search/cafearticle.json?query=mpop&display=100&start=801&sort=sim
# 200
# 전체 검색 데이터 수:  2630 검색할 페이지수:  27
# https://openapi.naver.com/v1/search/cafearticle.json?query=mpop&display=100&start=901&sort=sim
# 200
# 전체 검색 데이터 수:  2630 검색할 페이지수:  27
# https://openapi.naver.com/v1/search/cafearticle.json?query=mpop&display=100&start=1000&sort=sim
# 200
# 전체 검색 데이터 수:  2630 검색할 페이지수:  27

# %%
len(all_data2)
# Out:
# 11

# %%
final_result2 = pd.concat(all_data2)
final_result2 = final_result2.reset_index(drop=True)
final_result2
# Out:
#                                                   title  \
# 0                          삼성증권 <b>mpop</b> 어떤거 추천하시나요?
# 1                           삼성증권 <b>mpop</b> 쓰시는 분들께 문의
# 2                                    삼성증권 <b>mpop</b>에서
# 3                                     ㅋㅍㅈ <b>mpop</b>매출
# 4                삼성증권 <b>mPop</b>에 <b>mPop</b>-life 기능!
# ...                                                 ...
# 1095                                     주식 매수 질문(삼성증권)
# 1096  [종목뉴스][더퍼블릭][삼성증권] 05월05일 12시06분 어린이날 선물이 고민이라...
# 1097  [종목뉴스][청년일보][삼성증권] 05월05일 00시02분 삼성증권, '주식선물하기...
# 1098  [종목뉴스][비즈니스포스트][삼성증권] 05월01일 07시03분 [체험기] 삼성증권...
# 1099                                             하외주식매도
#
#                                            link  \
# 0     http://cafe.naver.com/likeusstock/1128837
# 1     http://cafe.naver.com/likeusstock/1156570
# 2          http://cafe.naver.com/pointns/516983
# 3        http://cafe.naver.com/seacoffee/195585
# 4      http://cafe.naver.com/stockschart/978802
# ...                                         ...
# 1095   http://cafe.naver.com/sharemoney12/12591
# 1096  http://cafe.naver.com/bluegrayur0zu/15382
# 1097  http://cafe.naver.com/bluegrayur0zu/15180
# 1098  http://cafe.naver.com/bluegrayur0zu/13517
# 1099   http://cafe.naver.com/sharemoney12/17728
#
#                                             description  \
# 0     Ui 좋다는 평이 많아 옮기려고 합니다 그냥 삼성증권도있고 <b>mpop</b>이라...
# 1     삼성증권 <b>mpop</b> 차트설정에 갭보정 기능이 들어있을까요? (증권사 어플...
# 2     질문드립니다 국내장화면에서는 여기에서 실시간 그래프가 보이는데 해외주식창과 금현물에...
# 3     안녕하세요. 오늘 오후 3시이후부터 키오스크 매출이 <b>mpop</b>에 안 잡히...
# 4     안녕하세요~ 오랜만에 글을 쓰는데요 오늘은 삼성증권 <b>mPop</b>의 기능 중...
# ...                                                 ...
# 1095  ㅠㅠ 증거금100%는 변경할 수 없는 걸까요ㅠㅠ 삼성증권<b>mpop</b>을 사용...
# 1096  ▣제목 : 어린이날 선물이 고민이라면?‥삼성증권, ‘주식 선물’ 하세요 ▣내용 : ...
# 1097  ▣제목 : 삼성증권, '주식선물하기' 서비스 오픈 ▣내용 : 보유 주식 외에도 신규...
# 1098  삼성증권의 모바일앱 엠팝(<b>mPOP</b>)을 실행하고 굴링 서비스에 가입하기까...
# 1099  삼성증권 <b>mpop</b> 사용중입니다 지식 공유 부탁드려요 아 그리고 여기는 ...
#
#                      cafename                               cafeurl
# 0                  미국 주식이 미래다    https://cafe.naver.com/likeusstock
# 1                  미국 주식이 미래다    https://cafe.naver.com/likeusstock
# 2     한국/미국주식 : 장기투자를 지향하는...        https://cafe.naver.com/pointns
# 3      ★테사모★프랜차이즈카페 사장모임-카...      https://cafe.naver.com/seacoffee
# 4     주식차트 연구소(주식 실제계좌 공개/...    https://cafe.naver.com/stockschart
# ...                       ...                                   ...
# 1095         재테크를 사랑하는 사람들 모임   https://cafe.naver.com/sharemoney12
# 1096               모두의 주식 놀이터  https://cafe.naver.com/bluegrayur0zu
# 1097               모두의 주식 놀이터  https://cafe.naver.com/bluegrayur0zu
# 1098               모두의 주식 놀이터  https://cafe.naver.com/bluegrayur0zu
# 1099         재테크를 사랑하는 사람들 모임   https://cafe.naver.com/sharemoney12
#
# [1100 rows x 5 columns]

# %%
final_result2.to_csv("네이버검색_카페.csv", encoding="utf-8-sig", index=False)

# %% [markdown]
# # 뉴스, 블로그, 책 한번에 검색해서 저장하기

# %%
all_data3 = []

for category in ["blog", "news", "cafearticle"]:
    start = 1
    while True:
        url = f"https://openapi.naver.com/v1/search/{category}.json"
        Client_Id = "sk2iKdMANqpvG3Pa2WIJ"
        Client_Secret = "by6xHZcrlB"
        headers = {"X-Naver-Client-Id" : Client_Id, "X-Naver-Client-Secret" : Client_Secret}
        payload = dict(query=keyword, display=100, start=start, sort="sim")
        r = requests.get(url, params=payload, headers=headers)
        print(r.url)
        print(r.status_code)
        data = r.json()
        n_data = data['total']
        total_pages = (int(data['total'])//100)+1
        print("전체 검색 데이터 수: ", n_data, "검색할 페이지수: ", total_pages )
        result_df = json_unpack(data)
        all_data3.append(result_df)
        if start == 1000:
            break
        elif start < 901:
            start += 100
        elif start == 901:
            start += 99
final_result3 = pd.concat(all_data3)
final_result3 = final_result3.reset_index(drop=True)
final_result3
# Out:
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=sim
# 200
# 전체 검색 데이터 수:  456148 검색할 페이지수:  4562
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=101&sort=sim
# 200
# 전체 검색 데이터 수:  456149 검색할 페이지수:  4562
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=201&sort=sim
# 200
# 전체 검색 데이터 수:  456148 검색할 페이지수:  4562
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=301&sort=sim
# 200
# 전체 검색 데이터 수:  456148 검색할 페이지수:  4562
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=401&sort=sim
# 200
# 전체 검색 데이터 수:  456148 검색할 페이지수:  4562
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=501&sort=sim
# 200
# 전체 검색 데이터 수:  456148 검색할 페이지수:  4562
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=601&sort=sim
# 200
# 전체 검색 데이터 수:  456149 검색할 페이지수:  4562
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=701&sort=sim
# 200
# 전체 검색 데이터 수:  456149 검색할 페이지수:  4562
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=801&sort=sim
# 200
# 전체 검색 데이터 수:  456148 검색할 페이지수:  4562
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=901&sort=sim
# 200
# 전체 검색 데이터 수:  456149 검색할 페이지수:  4562
# https://openapi.naver.com/v1/search/blog.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1000&sort=sim
# 200
# 전체 검색 데이터 수:  456148 검색할 페이지수:  4562
# https://openapi.naver.com/v1/search/news.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=sim
# 200
# 전체 검색 데이터 수:  498066 검색할 페이지수:  4981
# https://openapi.naver.com/v1/search/news.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=101&sort=sim
# 200
# 전체 검색 데이터 수:  498066 검색할 페이지수:  4981
# https://openapi.naver.com/v1/search/news.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=201&sort=sim
# 200
# 전체 검색 데이터 수:  498066 검색할 페이지수:  4981
# https://openapi.naver.com/v1/search/news.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=301&sort=sim
# 200
# 전체 검색 데이터 수:  498066 검색할 페이지수:  4981
# https://openapi.naver.com/v1/search/news.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=401&sort=sim
# 200
# 전체 검색 데이터 수:  498066 검색할 페이지수:  4981
# https://openapi.naver.com/v1/search/news.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=501&sort=sim
# 200
# 전체 검색 데이터 수:  498066 검색할 페이지수:  4981
# https://openapi.naver.com/v1/search/news.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=601&sort=sim
# 200
# 전체 검색 데이터 수:  498066 검색할 페이지수:  4981
# https://openapi.naver.com/v1/search/news.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=701&sort=sim
# 200
# 전체 검색 데이터 수:  498066 검색할 페이지수:  4981
# https://openapi.naver.com/v1/search/news.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=801&sort=sim
# 200
# 전체 검색 데이터 수:  498066 검색할 페이지수:  4981
# https://openapi.naver.com/v1/search/news.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=901&sort=sim
# 200
# 전체 검색 데이터 수:  498066 검색할 페이지수:  4981
# https://openapi.naver.com/v1/search/news.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1000&sort=sim
# 200
# 전체 검색 데이터 수:  498066 검색할 페이지수:  4981
# https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1&sort=sim
# 200
# 전체 검색 데이터 수:  106 검색할 페이지수:  2
# https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=101&sort=sim
# 200
# 전체 검색 데이터 수:  106 검색할 페이지수:  2
# https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=201&sort=sim
# 200
# 전체 검색 데이터 수:  106 검색할 페이지수:  2
# https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=301&sort=sim
# 200
# 전체 검색 데이터 수:  106 검색할 페이지수:  2
# https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=401&sort=sim
# 200
# 전체 검색 데이터 수:  106 검색할 페이지수:  2
# https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=501&sort=sim
# 200
# 전체 검색 데이터 수:  106 검색할 페이지수:  2
# https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=601&sort=sim
# 200
# 전체 검색 데이터 수:  106 검색할 페이지수:  2
# https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=701&sort=sim
# 200
# 전체 검색 데이터 수:  106 검색할 페이지수:  2
# https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=801&sort=sim
# 200
# 전체 검색 데이터 수:  106 검색할 페이지수:  2
# https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=901&sort=sim
# 200
# 전체 검색 데이터 수:  106 검색할 페이지수:  2
# https://openapi.naver.com/v1/search/book.json?query=%ED%95%80%ED%85%8C%ED%81%AC&display=100&start=1000&sort=sim
# 200
# 전체 검색 데이터 수:  106 검색할 페이지수:  2
#                                                   title  \
# 0                                      <b>핀테크</b> 투자 후기
# 1       [<b>핀테크</b>] 2024년 <b>핀테크</b> 업계 결산: 놀라운 3가지 변화
# 2      [인사이트 캠퍼스] 2025 동계 <b>핀테크</b> 캠프 (with 전주대학교...
# 3     [AI <b>핀테크</b>] AI와 빅데이터로 금융 시장을 재편하는 <b>핀테크</...
# 4          IPAY <b>핀테크</b>관련주 ETF -미국 CBDC 코인 서비스 실험 확대
# ...                                                 ...
# 2301  신남방 지역 주요국의 핀테크 발전과 협력방안: 인도, 태국, 말레이시아, 베트남, ...
# 2302  [CD] 2018 4차산업 기업.스타트업 주소록 - CD-ROM 1장 (가상현실·드...
# 2303  4차산업 기업·스타트업 주소록(2023)(CD) (IOT, VR, 가상현실, 블록체...
# 2304  4차산업 기업·스타트업 주소록(2024)(CD) (3D프린터, IOT, VR, 가상...
# 2305  전국 체험마을 주소록(2024)(CD) (3D프린터, IOT, VR, 가상현실, 드...
#
#                                                    link  \
# 0           https://blog.naver.com/kan1687/223812724931
# 1           https://blog.naver.com/xoom777/223708685044
# 2        https://blog.naver.com/fininsight/223734638126
# 3         https://blog.naver.com/jangpung_/223765345858
# 4             https://blog.naver.com/jaso_/223736810791
# ...                                                 ...
# 2301  https://search.shopping.naver.com/book/catalog...
# 2302  https://search.shopping.naver.com/book/catalog...
# 2303  https://search.shopping.naver.com/book/catalog...
# 2304  https://search.shopping.naver.com/book/catalog...
# 2305  https://search.shopping.naver.com/book/catalog...
#
#                                             description         bloggername  \
# 0     <b>핀테크</b> 투자, 아직도 망설이고 계신가요?  여러분 혹시 이런 고민 해보...                우정잉♥
# 1     동안 <b>핀테크</b> 업계에는 예상치 못한 변화의 바람이 불었습니다. 한동안 주...        Ich fange an
# 2     전주대학교 친구들이 직접 여의도까지 방문하여 <b>핀테크</b>(FinTech)의 ...  핀인사이트 (Fininsight)
# 3     이제 대출도 AI가 하는 시대 출처 : 파가야 테크놀러지스 홈페이지 금융과 기술이 ...          낭만을 꿈꾸는 일상
# 4     IPAY <b>핀테크</b>관련주 ETF -미국 CBDC 코인 서비스 실험 확대 I...            미국주식 퍼주마
# ...                                                 ...                 ...
# 2301  이 책은 대외경제정책연구원의 신남방 지역 주요국의 핀테크 발전과 협력방안을 다룬 정...                 NaN
# 2302  2018 4차산업 기업·스타트업 주소록 CD에는 4차 산업기술, 바이오헬스케어, 창...                 NaN
# 2303  4차산업 기업·스타트업 주소록을 분야별, 지역별로 18,460건, IT기업 상세정보...                 NaN
# 2304  4차산업 기업·스타트업 주소록을 분야별, 지역별로 19,908건, IT기업 상세정보...                 NaN
# 2305  전국 체험마을 주소록을 분야별, 지역별로 33,479건, 관광·여가산업 상세정보를 ...                 NaN
#
#                     bloggerlink  postdate originallink pubDate  \
# 0        blog.naver.com/kan1687  20250329          NaN     NaN
# 1        blog.naver.com/xoom777  20241229          NaN     NaN
# 2     blog.naver.com/fininsight  20250122          NaN     NaN
# 3      blog.naver.com/jangpung_  20250218          NaN     NaN
# 4          blog.naver.com/jaso_  20250130          NaN     NaN
# ...                         ...       ...          ...     ...
# 2301                        NaN       NaN          NaN     NaN
# 2302                        NaN       NaN          NaN     NaN
# 2303                        NaN       NaN          NaN     NaN
# 2304                        NaN       NaN          NaN     NaN
# 2305                        NaN       NaN          NaN     NaN
#
#                                                   image        author  \
# 0                                                   NaN           NaN
# 1                                                   NaN           NaN
# 2                                                   NaN           NaN
# 3                                                   NaN           NaN
# 4                                                   NaN           NaN
# ...                                                 ...           ...
# 2301  https://shopping-phinf.pstatic.net/main_332340...   이충열^이종하^이선호
# 2302  https://shopping-phinf.pstatic.net/main_324666...      한국콘텐츠미디어
# 2303  https://shopping-phinf.pstatic.net/main_400602...  한국콘텐츠미디어 편집부
# 2304  https://shopping-phinf.pstatic.net/main_466775...  한국콘텐츠미디어 편집부
# 2305  https://shopping-phinf.pstatic.net/main_466775...  한국콘텐츠미디어 편집부
#
#      discount  publisher   pubdate           isbn
# 0         NaN        NaN       NaN            NaN
# 1         NaN        NaN       NaN            NaN
# 2         NaN        NaN       NaN            NaN
# 3         NaN        NaN       NaN            NaN
# 4         NaN        NaN       NaN            NaN
# ...       ...        ...       ...            ...
# 2301     9000  대외경제정책연구원  20201231  9788932290201
# 2302   170100   한국콘텐츠미디어  20180921  9791155055663
# 2303   215100   한국콘텐츠미디어  20230501  8809496290337
# 2304   215100   한국콘텐츠미디어  20240326  9791172340209
# 2305   215100   한국콘텐츠미디어  20240322  9791172340193
#
# [2306 rows x 14 columns]
