# %%
# !pip install sqlalchemy

# %%
# !pip install pyMySQL

# %%
from datetime import datetime
today= datetime.now()
today= f"{today.year}_{today.month:02d}_{today.day:02d}"

# %%
df.to_csv(f"./scraping_results/상장기업정보_{today}기준.csv", encoding="utf-8")

# %% [markdown]
# - 4/4(금)
# ## 한번 생성하고 계속 복붙하라고 하신 부분.

# %%
from sqlalchemy import create_engine, text
import pymysql
pymysql.install_as_MySQLdb()

# %% [markdown]
# ![image.png](attachment:image.png)
# - sqlalchemy의 create_engine을 통해 mysql서버와 연결<br>
# engine=create_engine("mysql+pymysql://userid:password@ip주소>:/데이터베이스이름)
# ![image-2.png](attachment:image-2.png)

# %%
#stock_info 를 워크벤치에서 미리 생성한 다음 아래 명령) db접속시킴
engine=create_engine("mysql+pymysql://root:1234@localhost:3306/stock_info")
conn= engine.connect()
#create_engine에 있는 정보로 db접속.하는게 conn

# %%
#데이터프레임을 DB에 저장하기
# 데이터프레임명.to_sql("테이블명") 
df.to_sql(f"stock_company_info_{today}",con=conn, if_exists='update')
conn.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 #데이터프레임을 DB에 저장하기
#       2 # 데이터프레임명.to_sql("테이블명")
# ----> 3 df.to_sql(f"stock_company_info_{today}",con=conn, if_exists='update')
#
# NameError: name 'df' is not defined

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 판다스의 read_html을 이용해 table자료 한번에 가져오기
# - cmd에서 html5lib을 설치해야사용.
# ![image-2.png](attachment:image-2.png)

# %%
soup.select_one("table").text

# %%
pd.read_html() #표로된 html을 자동으로 데이터프레임화.

# %%
pd.read_html(soup.select_one("table").text ) #괄호에 넣어서 내용 가져오도록.

# %% [markdown]
# vs코드로 옮기기. 일단 vs코드 열고.<br>
# vs코드 시작할때의 옵션을 지정하기.
# ![image.png](attachment:image.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-5.png](attachment:image-5.png)
#
# 껐다 켜도 디폴트가 cmd로 되도록 설정.<br>
# stock_info.py 생성 후 인터프리터 설정
# ![image-6.png](attachment:image-6.png)
#
# 실무에서는 가상환경이 계속 달라질 수 있으니 이부분이 맞는지 항상확인해야함
# ![image-7.png](attachment:image-7.png)

# %% [markdown]
# 이제 전체 데이터도 붙여넣어주기. 0404:17:05
# ![image.png](attachment:image.png)
# 다른 환경에서 실행되게 하려면 실행파일을 만들기위해 인스톨러설치
# ![image-2.png](attachment:image-2.png)
# 파이인스톨러 사용법 관련 힌트: pyinstaller-help
# ![image-3.png](attachment:image-3.png)
# 마친 후 폴더가 생성된다.
# ![image-4.png](attachment:image-4.png)
# 다른 환경에서도 쓸수있는 파일은 dist폴더 내에있음.(실행하려면
# ![image-6.png](attachment:image-6.png)
# dist폴더 안에 하부폴더가 생성되도록 코딩.)
# ![image-5.png](attachment:image-5.png)
# 삭제해야할 것들▲ 용량만 먹음

# %% [markdown]
# gitignore 등록함
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
